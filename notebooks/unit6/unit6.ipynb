# %% [markdown]
# <a href="https://colab.research.google.com/github/huggingface/deep-rl-class/blob/main/notebooks/unit6/unit6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Unit 6: Advantage Actor Critic (A2C) using Robotics Simulations with Panda-Gym 🤖
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit8/thumbnail.png"  alt="Thumbnail"/>
#
# In this notebook, you'll learn to use A2C with [Panda-Gym](https://github.com/qgallouedec/panda-gym). You're going **to train a robotic arm** (Franka Emika Panda robot) to perform a task:
#
# - `Reach`: the robot must place its end-effector at a target position.
#
# After that, you'll be able **to train in other robotics tasks**.

# %% [markdown]
# ### 🎮 Environments:
#
# - [Panda-Gym](https://github.com/qgallouedec/panda-gym)
#
# ###📚 RL-Library:
#
# - [Stable-Baselines3](https://stable-baselines3.readthedocs.io/)

# %% [markdown]
# We're constantly trying to improve our tutorials, so **if you find some issues in this notebook**, please [open an issue on the GitHub Repo](https://github.com/huggingface/deep-rl-class/issues).

# %% [markdown]
# ## Objectives of this notebook 🏆
#
# At the end of the notebook, you will:
#
# - Be able to use **Panda-Gym**, the environment library.
# - Be able to **train robots using A2C**.
# - Understand why **we need to normalize the input**.
# - Be able to **push your trained agent and the code to the Hub** with a nice video replay and an evaluation score 🔥.

# %% [markdown]
# ## This notebook is from the Deep Reinforcement Learning Course
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/deep-rl-course-illustration.jpg" alt="Deep RL Course illustration"/>
#
# In this free course, you will:
#
# - 📖 Study Deep Reinforcement Learning in **theory and practice**.
# - 🧑‍💻 Learn to **use famous Deep RL libraries** such as Stable Baselines3, RL Baselines3 Zoo, CleanRL and Sample Factory 2.0.
# - 🤖 Train **agents in unique environments**
#
# And more check 📚 the syllabus 👉 https://simoninithomas.github.io/deep-rl-course
#
# Don’t forget to **<a href="http://eepurl.com/ic5ZUD">sign up to the course</a>** (we are collecting your email to be able to **send you the links when each Unit is published and give you information about the challenges and updates).**
#
#
# The best way to keep in touch is to join our discord server to exchange with the community and with us 👉🏻 https://discord.gg/ydHrjt3WP5

# %% [markdown]
# ## Prerequisites 🏗️
# Before diving into the notebook, you need to:
#
# 🔲 📚 Study [Actor-Critic methods by reading Unit 6](https://huggingface.co/deep-rl-course/unit6/introduction) 🤗

# %% [markdown]
# # Let's train our first robots 🤖

# %% [markdown]
# To validate this hands-on for the [certification process](https://huggingface.co/deep-rl-course/en/unit0/introduction#certification-process),  you need to push your trained model to the Hub and get the following results:
#
# - `PandaReachDense-v3` get a result of >= -3.5.
#
# To find your result, go to the [leaderboard](https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard) and find your model, **the result = mean_reward - std of reward**
#
# For more information about the certification process, check this section 👉 https://huggingface.co/deep-rl-course/en/unit0/introduction#certification-process

# %% [markdown]
# ## Set the GPU 💪
# - To **accelerate the agent's training, we'll use a GPU**. To do that, go to `Runtime > Change Runtime type`
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/gpu-step1.jpg" alt="GPU Step 1">

# %% [markdown]
# - `Hardware Accelerator > GPU`
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/gpu-step2.jpg" alt="GPU Step 2">

# %% [markdown]
# ## Create a virtual display 🔽
#
# During the notebook, we'll need to generate a replay video. To do so, with colab, **we need to have a virtual screen to be able to render the environment** (and thus record the frames).
#
# Hence the following cell will install the librairies and create and run a virtual screen 🖥

# %%
# %%capture
# !apt install python-opengl
# !apt install ffmpeg
# !apt install xvfb
# !pip3 install pyvirtualdisplay

# %%
# Virtual display
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %% [markdown]
# ### Install dependencies 🔽
#
# The first step is to install the dependencies, we’ll install multiple ones:
# - `gymnasium`
# - `panda-gym`: Contains the robotics arm environments.
# - `stable-baselines3`: The SB3 deep reinforcement learning library.
# - `huggingface_sb3`: Additional code for Stable-baselines3 to load and upload models from the Hugging Face 🤗 Hub.
# - `huggingface_hub`: Library allowing anyone to work with the Hub repositories.
#
# ⏲ The installation can **take 10 minutes**.

# %%
# !pip install stable-baselines3[extra]
# !pip install gymnasium
# Out:
# Requirement already satisfied: stable-baselines3[extra] in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (2.6.0)
# Requirement already satisfied: gymnasium<1.2.0,>=0.29.1 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from stable-baselines3[extra]) (1.1.1)
# Requirement already satisfied: numpy<3.0,>=1.20 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from stable-baselines3[extra]) (1.23.5)
# Requirement already satisfied: torch<3.0,>=2.3 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from stable-baselines3[extra]) (2.6.0)
# Requirement already satisfied: cloudpickle in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from stable-baselines3[extra]) (3.1.1)
# Requirement already satisfied: pandas in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from stable-baselines3[extra]) (2.2.3)
# Requirement already satisfied: matplotlib in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from stable-baselines3[extra]) (3.10.1)
# Requirement already satisfied: opencv-python in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from stable-baselines3[extra]) (4.11.0.86)
# Requirement already satisfied: pygame in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from stable-baselines3[extra]) (2.6.1)
# Requirement already satisfied: tensorboard>=2.9.1 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from stable-baselines3[extra]) (2.19.0)
# Requirement already satisfied: psutil in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from stable-baselines3[extra]) (7.0.0)
# Requirement already satisfied: tqdm in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from stable-baselines3[extra]) (4.67.1)
# Requirement already satisfied: rich in /home/stalaei/.local/lib/python3.10/site-packages (from stable-baselines3[extra]) (13.7.0)
# Requirement already satisfied: ale-py>=0.9.0 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from stable-baselines3[extra]) (0.10.2)
# Requirement already satisfied: pillow in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from stable-baselines3[extra]) (10.4.0)
# Requirement already satisfied: typing-extensions in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from ale-py>=0.9.0->stable-baselines3[extra]) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from gymnasium<1.2.0,>=0.29.1->stable-baselines3[extra]) (0.0.4)
# Requirement already satisfied: absl-py>=0.4 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.2.1)
# Requirement already satisfied: grpcio>=1.48.2 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.48.2)
# Requirement already satisfied: markdown>=2.6.8 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.7)
# Requirement already satisfied: packaging in /home/stalaei/.local/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (23.2)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.20.3)
# Requirement already satisfied: setuptools>=41.0.0 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (75.8.0)
# Requirement already satisfied: six>1.9 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.1.3)
# Requirement already satisfied: filelock in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (3.18.0)
# Requirement already satisfied: networkx in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (3.4.2)
# Requirement already satisfied: jinja2 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (3.1.6)
# Requirement already satisfied: fsspec in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from sympy==1.13.1->torch<3.0,>=2.3->stable-baselines3[extra]) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from matplotlib->stable-baselines3[extra]) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from matplotlib->stable-baselines3[extra]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from matplotlib->stable-baselines3[extra]) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from matplotlib->stable-baselines3[extra]) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from matplotlib->stable-baselines3[extra]) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from matplotlib->stable-baselines3[extra]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from pandas->stable-baselines3[extra]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from pandas->stable-baselines3[extra]) (2025.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/stalaei/.local/lib/python3.10/site-packages (from rich->stable-baselines3[extra]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/stalaei/.local/lib/python3.10/site-packages (from rich->stable-baselines3[extra]) (2.17.2)
# Requirement already satisfied: mdurl~=0.1 in /home/stalaei/.local/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]) (3.0.2)
# Requirement already satisfied: gymnasium in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (1.1.1)
# Requirement already satisfied: numpy>=1.21.0 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from gymnasium) (1.23.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from gymnasium) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from gymnasium) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from gymnasium) (0.0.4)

# %%
# !pip install huggingface_sb3
# !pip install huggingface_hub
# !pip install panda_gym
# Out:
# Requirement already satisfied: huggingface_sb3 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (3.0)
# Requirement already satisfied: huggingface-hub~=0.8 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from huggingface_sb3) (0.29.3)
# Requirement already satisfied: pyyaml~=6.0 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from huggingface_sb3) (6.0)
# Requirement already satisfied: wasabi in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from huggingface_sb3) (1.1.3)
# Requirement already satisfied: numpy in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from huggingface_sb3) (1.23.5)
# Requirement already satisfied: cloudpickle>=1.6 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from huggingface_sb3) (3.1.1)
# Requirement already satisfied: filelock in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from huggingface-hub~=0.8->huggingface_sb3) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from huggingface-hub~=0.8->huggingface_sb3) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /home/stalaei/.local/lib/python3.10/site-packages (from huggingface-hub~=0.8->huggingface_sb3) (23.2)
# Requirement already satisfied: requests in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from huggingface-hub~=0.8->huggingface_sb3) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from huggingface-hub~=0.8->huggingface_sb3) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from huggingface-hub~=0.8->huggingface_sb3) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from requests->huggingface-hub~=0.8->huggingface_sb3) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from requests->huggingface-hub~=0.8->huggingface_sb3) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from requests->huggingface-hub~=0.8->huggingface_sb3) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from requests->huggingface-hub~=0.8->huggingface_sb3) (2025.1.31)
# Requirement already satisfied: huggingface_hub in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (0.29.3)
# Requirement already satisfied: filelock in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from huggingface_hub) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from huggingface_hub) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /home/stalaei/.local/lib/python3.10/site-packages (from huggingface_hub) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from huggingface_hub) (6.0)
# Requirement already satisfied: requests in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from huggingface_hub) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from huggingface_hub) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from huggingface_hub) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from requests->huggingface_hub) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from requests->huggingface_hub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from requests->huggingface_hub) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from requests->huggingface_hub) (2025.1.31)
# Collecting panda_gym
#   Downloading panda_gym-3.0.7-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: gymnasium>=0.26 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from panda_gym) (1.1.1)
# Collecting pybullet (from panda_gym)
#   Downloading pybullet-3.2.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: numpy in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from panda_gym) (1.23.5)
# Collecting scipy (from panda_gym)
#   Using cached scipy-1.15.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from gymnasium>=0.26->panda_gym) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from gymnasium>=0.26->panda_gym) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from gymnasium>=0.26->panda_gym) (0.0.4)
# Downloading panda_gym-3.0.7-py3-none-any.whl (23 kB)
# Downloading pybullet-3.2.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (103.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.2/103.2 MB 37.8 MB/s eta 0:00:0000:010:01
# Using cached scipy-1.15.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.6 MB)
# Installing collected packages: pybullet, scipy, panda_gym
# Successfully installed panda_gym-3.0.7 pybullet-3.2.7 scipy-1.15.2

# %% [markdown]
# ## Import the packages 📦

# %%
import os

import gymnasium as gym
import panda_gym

from huggingface_sb3 import load_from_hub, package_to_hub

from stable_baselines3 import A2C
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
from stable_baselines3.common.env_util import make_vec_env

from huggingface_hub import notebook_login

# %% [markdown]
# ## PandaReachDense-v3 🦾
#
# The agent we're going to train is a robotic arm that needs to do controls (moving the arm and using the end-effector).
#
# In robotics, the *end-effector* is the device at the end of a robotic arm designed to interact with the environment.
#
# In `PandaReach`, the robot must place its end-effector at a target position (green ball).
#
# We're going to use the dense version of this environment. It means we'll get a *dense reward function* that **will provide a reward at each timestep** (the closer the agent is to completing the task, the higher the reward). Contrary to a *sparse reward function* where the environment **return a reward if and only if the task is completed**.
#
# Also, we're going to use the *End-effector displacement control*, it means the **action corresponds to the displacement of the end-effector**. We don't control the individual motion of each joint (joint control).
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit8/robotics.jpg"  alt="Robotics"/>
#
#
# This way **the training will be easier**.

# %% [markdown]
# ### Create the environment
#
# #### The environment 🎮
#
# In `PandaReachDense-v3` the robotic arm must place its end-effector at a target position (green ball).

# %%
env_id = "PandaReachDense-v3"

# Create the env
env = gym.make(env_id)

# Get the state space and action space
s_size = env.observation_space.shape
a_size = env.action_space
# Out:
# pybullet build time: Jan 29 2025 23:16:28
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886

# %%
print("_____OBSERVATION SPACE_____ \n")
print("The State Space is: ", s_size)
print("Sample observation", env.observation_space.sample()) # Get a random observation
# Out:
# _____OBSERVATION SPACE_____
#
# The State Space is:  None
# Sample observation {'achieved_goal': array([-9.805814 ,  9.801961 ,  1.1000526], dtype=float32), 'desired_goal': array([ 4.194464, -3.193849,  8.274864], dtype=float32), 'observation': array([ 2.5412984,  1.0897018,  4.841302 , -3.5231042, -3.8836823,
#         6.548211 ], dtype=float32)}

# %% [markdown]
# The observation space **is a dictionary with 3 different elements**:
# - `achieved_goal`: (x,y,z) the current position of the end-effector.
# - `desired_goal`: (x,y,z) the target position for the end-effector.
# - `observation`: position (x,y,z) and velocity of the end-effector (vx, vy, vz).
#
# Given it's a dictionary as observation, **we will need to use a MultiInputPolicy policy instead of MlpPolicy**.

# %%
print("\n _____ACTION SPACE_____ \n")
print("The Action Space is: ", a_size)
print("Action Space Sample", env.action_space.sample()) # Take a random action
# Out:
#  _____ACTION SPACE_____
#
# The Action Space is:  Box(-1.0, 1.0, (3,), float32)
# Action Space Sample [-0.28213283 -0.9448414  -0.41663006]

# %% [markdown]
# The action space is a vector with 3 values:
# - Control x, y, z movement

# %% [markdown]
# ### Normalize observation and rewards

# %% [markdown]
# A good practice in reinforcement learning is to [normalize input features](https://stable-baselines3.readthedocs.io/en/master/guide/rl_tips.html).
#
# For that purpose, there is a wrapper that will compute a running average and standard deviation of input features.
#
# We also normalize rewards with this same wrapper by adding `norm_reward = True`
#
# [You should check the documentation to fill this cell](https://stable-baselines3.readthedocs.io/en/master/guide/vec_envs.html#vecnormalize)

# %%
env = make_vec_env(env_id, n_envs=4)

# Adding this wrapper to normalize the observation and the reward
env = VecNormalize(env, norm_obs=True, norm_reward=True, clip_obs=10.)
# Out:
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886

# %% [markdown]
# #### Solution

# %%
env = make_vec_env(env_id, n_envs=4)

env = VecNormalize(env, norm_obs=True, norm_reward=True, clip_obs=10.)

# %% [markdown]
# ### Create the A2C Model 🤖
#
# For more information about A2C implementation with StableBaselines3 check: https://stable-baselines3.readthedocs.io/en/master/modules/a2c.html#notes
#
# To find the best parameters I checked the [official trained agents by Stable-Baselines3 team](https://huggingface.co/sb3).

# %%
model = A2C(
    policy = "MultiInputPolicy",
    env = env,
    verbose=1
)
# Create the A2C model and try to find the best parameters
# Out:
# Using cuda device

# %% [markdown]
# #### Solution

# %%
model = A2C(policy = "MultiInputPolicy",
            env = env,
            verbose=1)

# %% [markdown]
# ### Train the A2C agent 🏃
# - Let's train our agent for 1,000,000 timesteps, don't forget to use GPU on Colab. It will take approximately ~25-40min

# %%
model.learn(1_000_000)
# Out:
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 46.7     |
# |    ep_rew_mean        | -13      |
# |    success_rate       | 0.1      |
# | time/                 |          |
# |    fps                | 530      |
# |    iterations         | 100      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -4.27    |
# |    explained_variance | 0.826    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | -0.121   |
# |    std                | 1        |
# |    value_loss         | 0.0604   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48.3     |
# |    ep_rew_mean        | -13.4    |
# |    success_rate       | 0.0625   |
# | time/                 |          |
# |    fps                | 556      |
# |    iterations         | 200      |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -4.26    |
# |    explained_variance | 0.978    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | -0.668   |
# |    std                | 1        |
# |    value_loss         | 0.0501   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48.1     |
# |    ep_rew_mean        | -14.6    |
# |    success_rate       | 0.05     |
# | time/                 |          |
# |    fps                | 567      |
# |    iterations         | 300      |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -4.3     |
# |    explained_variance | 0.691    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | -1.42    |
# |    std                | 1.01     |
# |    value_loss         | 0.203    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 44.3     |
# |    ep_rew_mean        | -14.5    |
# |    success_rate       | 0.13     |
# | time/                 |          |
# |    fps                | 572      |
# |    iterations         | 400      |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -4.3     |
# |    explained_variance | 0.953    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | 0.237    |
# |    std                | 1.02     |
# |    value_loss         | 0.096    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 43.7     |
# |    ep_rew_mean        | -13.3    |
# |    success_rate       | 0.14     |
# | time/                 |          |
# |    fps                | 575      |
# |    iterations         | 500      |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -4.31    |
# |    explained_variance | 0.924    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | -0.269   |
# |    std                | 1.02     |
# |    value_loss         | 0.0291   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 45.6     |
# |    ep_rew_mean        | -13.2    |
# |    success_rate       | 0.1      |
# | time/                 |          |
# |    fps                | 575      |
# |    iterations         | 600      |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -4.3     |
# |    explained_variance | 0.968    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | -0.0801  |
# |    std                | 1.01     |
# |    value_loss         | 0.0341   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 46.9     |
# |    ep_rew_mean        | -12.6    |
# |    success_rate       | 0.07     |
# | time/                 |          |
# |    fps                | 577      |
# |    iterations         | 700      |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -4.3     |
# |    explained_variance | 0.967    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | 0.0231   |
# |    std                | 1.01     |
# |    value_loss         | 0.0226   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 45       |
# |    ep_rew_mean        | -11.9    |
# |    success_rate       | 0.11     |
# | time/                 |          |
# |    fps                | 576      |
# |    iterations         | 800      |
# |    time_elapsed       | 27       |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -4.28    |
# |    explained_variance | 0.983    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | 0.192    |
# |    std                | 1.01     |
# |    value_loss         | 0.0199   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 45.4     |
# |    ep_rew_mean        | -14      |
# |    success_rate       | 0.1      |
# | time/                 |          |
# |    fps                | 572      |
# |    iterations         | 900      |
# |    time_elapsed       | 31       |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -4.28    |
# |    explained_variance | 0.891    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | 0.801    |
# |    std                | 1.01     |
# |    value_loss         | 0.549    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 47.7     |
# |    ep_rew_mean        | -15.6    |
# |    success_rate       | 0.05     |
# | time/                 |          |
# |    fps                | 565      |
# |    iterations         | 1000     |
# |    time_elapsed       | 35       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -4.27    |
# |    explained_variance | 0.993    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | 0.129    |
# |    std                | 1        |
# |    value_loss         | 0.0158   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 44.5     |
# |    ep_rew_mean        | -13.1    |
# |    success_rate       | 0.12     |
# | time/                 |          |
# |    fps                | 562      |
# |    iterations         | 1100     |
# |    time_elapsed       | 39       |
# |    total_timesteps    | 22000    |
# | train/                |          |
# |    entropy_loss       | -4.29    |
# |    explained_variance | 0.888    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | 1.88     |
# |    std                | 1.01     |
# |    value_loss         | 1.14     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 42.5     |
# |    ep_rew_mean        | -10.8    |
# |    success_rate       | 0.17     |
# | time/                 |          |
# |    fps                | 562      |
# |    iterations         | 1200     |
# |    time_elapsed       | 42       |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -4.29    |
# |    explained_variance | 0.982    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | -0.226   |
# |    std                | 1.01     |
# |    value_loss         | 0.0324   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 41.4     |
# |    ep_rew_mean        | -10.9    |
# |    success_rate       | 0.2      |
# | time/                 |          |
# |    fps                | 563      |
# |    iterations         | 1300     |
# |    time_elapsed       | 46       |
# |    total_timesteps    | 26000    |
# | train/                |          |
# |    entropy_loss       | -4.3     |
# |    explained_variance | 0.987    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | -0.642   |
# |    std                | 1.02     |
# |    value_loss         | 0.0997   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 43.7     |
# |    ep_rew_mean        | -12.2    |
# |    success_rate       | 0.14     |
# | time/                 |          |
# |    fps                | 566      |
# |    iterations         | 1400     |
# |    time_elapsed       | 49       |
# |    total_timesteps    | 28000    |
# | train/                |          |
# |    entropy_loss       | -4.3     |
# |    explained_variance | 0.99     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | 0.263    |
# |    std                | 1.01     |
# |    value_loss         | 0.0197   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 41.3     |
# |    ep_rew_mean        | -11      |
# |    success_rate       | 0.2      |
# | time/                 |          |
# |    fps                | 569      |
# |    iterations         | 1500     |
# |    time_elapsed       | 52       |
# |    total_timesteps    | 30000    |
# | train/                |          |
# |    entropy_loss       | -4.27    |
# |    explained_variance | 0.999    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | 0.227    |
# |    std                | 1        |
# |    value_loss         | 0.00605  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 39.8     |
# |    ep_rew_mean        | -9.58    |
# |    success_rate       | 0.25     |
# | time/                 |          |
# |    fps                | 573      |
# |    iterations         | 1600     |
# |    time_elapsed       | 55       |
# |    total_timesteps    | 32000    |
# | train/                |          |
# |    entropy_loss       | -4.28    |
# |    explained_variance | 0.543    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1599     |
# |    policy_loss        | 4.85     |
# |    std                | 1.01     |
# |    value_loss         | 3.97     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 40.4     |
# |    ep_rew_mean        | -9.81    |
# |    success_rate       | 0.24     |
# | time/                 |          |
# |    fps                | 576      |
# |    iterations         | 1700     |
# |    time_elapsed       | 58       |
# |    total_timesteps    | 34000    |
# | train/                |          |
# |    entropy_loss       | -4.28    |
# |    explained_variance | 0.838    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | -0.487   |
# |    std                | 1.01     |
# |    value_loss         | 0.152    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 38.6     |
# |    ep_rew_mean        | -9.58    |
# |    success_rate       | 0.28     |
# | time/                 |          |
# |    fps                | 579      |
# |    iterations         | 1800     |
# |    time_elapsed       | 62       |
# |    total_timesteps    | 36000    |
# | train/                |          |
# |    entropy_loss       | -4.27    |
# |    explained_variance | 0.984    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | -0.454   |
# |    std                | 1        |
# |    value_loss         | 0.0385   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 38.8     |
# |    ep_rew_mean        | -8.83    |
# |    success_rate       | 0.29     |
# | time/                 |          |
# |    fps                | 582      |
# |    iterations         | 1900     |
# |    time_elapsed       | 65       |
# |    total_timesteps    | 38000    |
# | train/                |          |
# |    entropy_loss       | -4.28    |
# |    explained_variance | 0.98     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | -0.0863  |
# |    std                | 1.01     |
# |    value_loss         | 0.0131   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 37.5     |
# |    ep_rew_mean        | -7.94    |
# |    success_rate       | 0.35     |
# | time/                 |          |
# |    fps                | 584      |
# |    iterations         | 2000     |
# |    time_elapsed       | 68       |
# |    total_timesteps    | 40000    |
# | train/                |          |
# |    entropy_loss       | -4.3     |
# |    explained_variance | 0.978    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1999     |
# |    policy_loss        | -0.562   |
# |    std                | 1.01     |
# |    value_loss         | 0.0326   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 32.8     |
# |    ep_rew_mean        | -6.07    |
# |    success_rate       | 0.52     |
# | time/                 |          |
# |    fps                | 586      |
# |    iterations         | 2100     |
# |    time_elapsed       | 71       |
# |    total_timesteps    | 42000    |
# | train/                |          |
# |    entropy_loss       | -4.28    |
# |    explained_variance | 0.236    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2099     |
# |    policy_loss        | 3.3      |
# |    std                | 1.01     |
# |    value_loss         | 2.6      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 33.9     |
# |    ep_rew_mean        | -5.84    |
# |    success_rate       | 0.53     |
# | time/                 |          |
# |    fps                | 588      |
# |    iterations         | 2200     |
# |    time_elapsed       | 74       |
# |    total_timesteps    | 44000    |
# | train/                |          |
# |    entropy_loss       | -4.27    |
# |    explained_variance | 0.972    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2199     |
# |    policy_loss        | -0.283   |
# |    std                | 1.01     |
# |    value_loss         | 0.0184   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 34.1     |
# |    ep_rew_mean        | -5.77    |
# |    success_rate       | 0.55     |
# | time/                 |          |
# |    fps                | 590      |
# |    iterations         | 2300     |
# |    time_elapsed       | 77       |
# |    total_timesteps    | 46000    |
# | train/                |          |
# |    entropy_loss       | -4.26    |
# |    explained_variance | 0.944    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2299     |
# |    policy_loss        | 0.0889   |
# |    std                | 1        |
# |    value_loss         | 0.0102   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 25.6     |
# |    ep_rew_mean        | -4.05    |
# |    success_rate       | 0.73     |
# | time/                 |          |
# |    fps                | 592      |
# |    iterations         | 2400     |
# |    time_elapsed       | 81       |
# |    total_timesteps    | 48000    |
# | train/                |          |
# |    entropy_loss       | -4.24    |
# |    explained_variance | 0.285    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2399     |
# |    policy_loss        | 3.08     |
# |    std                | 0.995    |
# |    value_loss         | 1.24     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 23.8     |
# |    ep_rew_mean        | -3.42    |
# |    success_rate       | 0.79     |
# | time/                 |          |
# |    fps                | 593      |
# |    iterations         | 2500     |
# |    time_elapsed       | 84       |
# |    total_timesteps    | 50000    |
# | train/                |          |
# |    entropy_loss       | -4.2     |
# |    explained_variance | 0.758    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2499     |
# |    policy_loss        | 1.29     |
# |    std                | 0.983    |
# |    value_loss         | 0.409    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20.5     |
# |    ep_rew_mean        | -2.83    |
# |    success_rate       | 0.84     |
# | time/                 |          |
# |    fps                | 595      |
# |    iterations         | 2600     |
# |    time_elapsed       | 87       |
# |    total_timesteps    | 52000    |
# | train/                |          |
# |    entropy_loss       | -4.18    |
# |    explained_variance | -2.58    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2599     |
# |    policy_loss        | 1.29     |
# |    std                | 0.976    |
# |    value_loss         | 0.762    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 10.5     |
# |    ep_rew_mean        | -1.14    |
# |    success_rate       | 0.99     |
# | time/                 |          |
# |    fps                | 597      |
# |    iterations         | 2700     |
# |    time_elapsed       | 90       |
# |    total_timesteps    | 54000    |
# | train/                |          |
# |    entropy_loss       | -4.13    |
# |    explained_variance | 0.0715   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2699     |
# |    policy_loss        | 0.318    |
# |    std                | 0.959    |
# |    value_loss         | 0.123    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.69     |
# |    ep_rew_mean        | -0.756   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 599      |
# |    iterations         | 2800     |
# |    time_elapsed       | 93       |
# |    total_timesteps    | 56000    |
# | train/                |          |
# |    entropy_loss       | -4.09    |
# |    explained_variance | -0.483   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2799     |
# |    policy_loss        | 0.591    |
# |    std                | 0.945    |
# |    value_loss         | 0.122    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.29     |
# |    ep_rew_mean        | -0.452   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 600      |
# |    iterations         | 2900     |
# |    time_elapsed       | 96       |
# |    total_timesteps    | 58000    |
# | train/                |          |
# |    entropy_loss       | -4.04    |
# |    explained_variance | -2.58    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2899     |
# |    policy_loss        | 0.282    |
# |    std                | 0.931    |
# |    value_loss         | 0.0263   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.69     |
# |    ep_rew_mean        | -0.393   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 601      |
# |    iterations         | 3000     |
# |    time_elapsed       | 99       |
# |    total_timesteps    | 60000    |
# | train/                |          |
# |    entropy_loss       | -4       |
# |    explained_variance | 0.321    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2999     |
# |    policy_loss        | -0.158   |
# |    std                | 0.917    |
# |    value_loss         | 0.0072   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.12     |
# |    ep_rew_mean        | -0.333   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 603      |
# |    iterations         | 3100     |
# |    time_elapsed       | 102      |
# |    total_timesteps    | 62000    |
# | train/                |          |
# |    entropy_loss       | -3.93    |
# |    explained_variance | -2.15    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3099     |
# |    policy_loss        | -0.142   |
# |    std                | 0.897    |
# |    value_loss         | 0.00387  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.44     |
# |    ep_rew_mean        | -0.279   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 604      |
# |    iterations         | 3200     |
# |    time_elapsed       | 105      |
# |    total_timesteps    | 64000    |
# | train/                |          |
# |    entropy_loss       | -3.89    |
# |    explained_variance | 0.515    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3199     |
# |    policy_loss        | 0.0078   |
# |    std                | 0.884    |
# |    value_loss         | 0.00114  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.44     |
# |    ep_rew_mean        | -0.271   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 605      |
# |    iterations         | 3300     |
# |    time_elapsed       | 109      |
# |    total_timesteps    | 66000    |
# | train/                |          |
# |    entropy_loss       | -3.85    |
# |    explained_variance | -0.0292  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3299     |
# |    policy_loss        | -0.0698  |
# |    std                | 0.872    |
# |    value_loss         | 0.00247  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.45     |
# |    ep_rew_mean        | -0.273   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 606      |
# |    iterations         | 3400     |
# |    time_elapsed       | 112      |
# |    total_timesteps    | 68000    |
# | train/                |          |
# |    entropy_loss       | -3.81    |
# |    explained_variance | -0.866   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3399     |
# |    policy_loss        | -0.023   |
# |    std                | 0.861    |
# |    value_loss         | 0.000587 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.66     |
# |    ep_rew_mean        | -0.296   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 607      |
# |    iterations         | 3500     |
# |    time_elapsed       | 115      |
# |    total_timesteps    | 70000    |
# | train/                |          |
# |    entropy_loss       | -3.77    |
# |    explained_variance | -0.316   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3499     |
# |    policy_loss        | 0.02     |
# |    std                | 0.851    |
# |    value_loss         | 0.00148  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.2      |
# |    ep_rew_mean        | -0.251   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 608      |
# |    iterations         | 3600     |
# |    time_elapsed       | 118      |
# |    total_timesteps    | 72000    |
# | train/                |          |
# |    entropy_loss       | -3.71    |
# |    explained_variance | -0.438   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3599     |
# |    policy_loss        | 0.0793   |
# |    std                | 0.835    |
# |    value_loss         | 0.00269  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.29     |
# |    ep_rew_mean        | -0.26    |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 608      |
# |    iterations         | 3700     |
# |    time_elapsed       | 121      |
# |    total_timesteps    | 74000    |
# | train/                |          |
# |    entropy_loss       | -3.67    |
# |    explained_variance | 0.638    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3699     |
# |    policy_loss        | -0.06    |
# |    std                | 0.823    |
# |    value_loss         | 0.000648 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.12     |
# |    ep_rew_mean        | -0.24    |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 609      |
# |    iterations         | 3800     |
# |    time_elapsed       | 124      |
# |    total_timesteps    | 76000    |
# | train/                |          |
# |    entropy_loss       | -3.63    |
# |    explained_variance | 0.474    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3799     |
# |    policy_loss        | -0.0314  |
# |    std                | 0.81     |
# |    value_loss         | 0.000582 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.17     |
# |    ep_rew_mean        | -0.244   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 610      |
# |    iterations         | 3900     |
# |    time_elapsed       | 127      |
# |    total_timesteps    | 78000    |
# | train/                |          |
# |    entropy_loss       | -3.62    |
# |    explained_variance | 0.121    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3899     |
# |    policy_loss        | -0.0502  |
# |    std                | 0.808    |
# |    value_loss         | 0.00106  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.04     |
# |    ep_rew_mean        | -0.243   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 610      |
# |    iterations         | 4000     |
# |    time_elapsed       | 131      |
# |    total_timesteps    | 80000    |
# | train/                |          |
# |    entropy_loss       | -3.59    |
# |    explained_variance | 0.562    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3999     |
# |    policy_loss        | 0.128    |
# |    std                | 0.802    |
# |    value_loss         | 0.00254  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.14     |
# |    ep_rew_mean        | -0.244   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 611      |
# |    iterations         | 4100     |
# |    time_elapsed       | 134      |
# |    total_timesteps    | 82000    |
# | train/                |          |
# |    entropy_loss       | -3.54    |
# |    explained_variance | 0.382    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4099     |
# |    policy_loss        | 0.0151   |
# |    std                | 0.788    |
# |    value_loss         | 0.000463 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.07     |
# |    ep_rew_mean        | -0.24    |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 611      |
# |    iterations         | 4200     |
# |    time_elapsed       | 137      |
# |    total_timesteps    | 84000    |
# | train/                |          |
# |    entropy_loss       | -3.5     |
# |    explained_variance | -0.0306  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4199     |
# |    policy_loss        | -0.159   |
# |    std                | 0.776    |
# |    value_loss         | 0.00275  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.82     |
# |    ep_rew_mean        | -0.212   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 612      |
# |    iterations         | 4300     |
# |    time_elapsed       | 140      |
# |    total_timesteps    | 86000    |
# | train/                |          |
# |    entropy_loss       | -3.46    |
# |    explained_variance | 0.576    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4299     |
# |    policy_loss        | 0.0577   |
# |    std                | 0.766    |
# |    value_loss         | 0.000998 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.15     |
# |    ep_rew_mean        | -0.243   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 613      |
# |    iterations         | 4400     |
# |    time_elapsed       | 143      |
# |    total_timesteps    | 88000    |
# | train/                |          |
# |    entropy_loss       | -3.43    |
# |    explained_variance | 0.71     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4399     |
# |    policy_loss        | -0.0144  |
# |    std                | 0.758    |
# |    value_loss         | 0.000298 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.22     |
# |    ep_rew_mean        | -0.253   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 614      |
# |    iterations         | 4500     |
# |    time_elapsed       | 146      |
# |    total_timesteps    | 90000    |
# | train/                |          |
# |    entropy_loss       | -3.41    |
# |    explained_variance | 0.519    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4499     |
# |    policy_loss        | -0.0229  |
# |    std                | 0.755    |
# |    value_loss         | 0.000471 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.05     |
# |    ep_rew_mean        | -0.245   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 614      |
# |    iterations         | 4600     |
# |    time_elapsed       | 149      |
# |    total_timesteps    | 92000    |
# | train/                |          |
# |    entropy_loss       | -3.39    |
# |    explained_variance | 0.435    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4599     |
# |    policy_loss        | 0.00995  |
# |    std                | 0.75     |
# |    value_loss         | 0.000589 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.96     |
# |    ep_rew_mean        | -0.226   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 615      |
# |    iterations         | 4700     |
# |    time_elapsed       | 152      |
# |    total_timesteps    | 94000    |
# | train/                |          |
# |    entropy_loss       | -3.38    |
# |    explained_variance | 0.528    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4699     |
# |    policy_loss        | -0.0199  |
# |    std                | 0.748    |
# |    value_loss         | 0.000361 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.03     |
# |    ep_rew_mean        | -0.243   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 616      |
# |    iterations         | 4800     |
# |    time_elapsed       | 155      |
# |    total_timesteps    | 96000    |
# | train/                |          |
# |    entropy_loss       | -3.37    |
# |    explained_variance | -3.52    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4799     |
# |    policy_loss        | 0.115    |
# |    std                | 0.745    |
# |    value_loss         | 0.00502  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.88     |
# |    ep_rew_mean        | -0.224   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 616      |
# |    iterations         | 4900     |
# |    time_elapsed       | 158      |
# |    total_timesteps    | 98000    |
# | train/                |          |
# |    entropy_loss       | -3.34    |
# |    explained_variance | 0.903    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4899     |
# |    policy_loss        | 0.0192   |
# |    std                | 0.736    |
# |    value_loss         | 0.000183 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.02     |
# |    ep_rew_mean        | -0.237   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 617      |
# |    iterations         | 5000     |
# |    time_elapsed       | 162      |
# |    total_timesteps    | 100000   |
# | train/                |          |
# |    entropy_loss       | -3.34    |
# |    explained_variance | 0.433    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4999     |
# |    policy_loss        | -0.0134  |
# |    std                | 0.735    |
# |    value_loss         | 0.000802 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.89     |
# |    ep_rew_mean        | -0.224   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 617      |
# |    iterations         | 5100     |
# |    time_elapsed       | 165      |
# |    total_timesteps    | 102000   |
# | train/                |          |
# |    entropy_loss       | -3.3     |
# |    explained_variance | 0.783    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5099     |
# |    policy_loss        | 0.0204   |
# |    std                | 0.728    |
# |    value_loss         | 0.000207 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.82     |
# |    ep_rew_mean        | -0.215   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 618      |
# |    iterations         | 5200     |
# |    time_elapsed       | 168      |
# |    total_timesteps    | 104000   |
# | train/                |          |
# |    entropy_loss       | -3.27    |
# |    explained_variance | 0.819    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5199     |
# |    policy_loss        | -0.0226  |
# |    std                | 0.72     |
# |    value_loss         | 0.000107 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.83     |
# |    ep_rew_mean        | -0.228   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 618      |
# |    iterations         | 5300     |
# |    time_elapsed       | 171      |
# |    total_timesteps    | 106000   |
# | train/                |          |
# |    entropy_loss       | -3.25    |
# |    explained_variance | 0.73     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5299     |
# |    policy_loss        | 0.014    |
# |    std                | 0.715    |
# |    value_loss         | 0.00039  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.1      |
# |    ep_rew_mean        | -0.245   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 618      |
# |    iterations         | 5400     |
# |    time_elapsed       | 174      |
# |    total_timesteps    | 108000   |
# | train/                |          |
# |    entropy_loss       | -3.2     |
# |    explained_variance | 0.233    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5399     |
# |    policy_loss        | -0.0459  |
# |    std                | 0.703    |
# |    value_loss         | 0.00142  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.98     |
# |    ep_rew_mean        | -0.233   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 619      |
# |    iterations         | 5500     |
# |    time_elapsed       | 177      |
# |    total_timesteps    | 110000   |
# | train/                |          |
# |    entropy_loss       | -3.17    |
# |    explained_variance | 0.865    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5499     |
# |    policy_loss        | -0.028   |
# |    std                | 0.695    |
# |    value_loss         | 0.000201 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.08     |
# |    ep_rew_mean        | -0.239   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 619      |
# |    iterations         | 5600     |
# |    time_elapsed       | 180      |
# |    total_timesteps    | 112000   |
# | train/                |          |
# |    entropy_loss       | -3.14    |
# |    explained_variance | 0.704    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5599     |
# |    policy_loss        | 0.0258   |
# |    std                | 0.688    |
# |    value_loss         | 0.000247 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.94     |
# |    ep_rew_mean        | -0.231   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 619      |
# |    iterations         | 5700     |
# |    time_elapsed       | 183      |
# |    total_timesteps    | 114000   |
# | train/                |          |
# |    entropy_loss       | -3.12    |
# |    explained_variance | -0.281   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5699     |
# |    policy_loss        | -0.165   |
# |    std                | 0.684    |
# |    value_loss         | 0.00455  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.9      |
# |    ep_rew_mean        | -0.228   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 620      |
# |    iterations         | 5800     |
# |    time_elapsed       | 187      |
# |    total_timesteps    | 116000   |
# | train/                |          |
# |    entropy_loss       | -3.1     |
# |    explained_variance | 0.914    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5799     |
# |    policy_loss        | 0.0316   |
# |    std                | 0.68     |
# |    value_loss         | 0.000212 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.88     |
# |    ep_rew_mean        | -0.228   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 620      |
# |    iterations         | 5900     |
# |    time_elapsed       | 190      |
# |    total_timesteps    | 118000   |
# | train/                |          |
# |    entropy_loss       | -3.08    |
# |    explained_variance | -0.0755  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5899     |
# |    policy_loss        | 0.0644   |
# |    std                | 0.676    |
# |    value_loss         | 0.00158  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.8      |
# |    ep_rew_mean        | -0.208   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 620      |
# |    iterations         | 6000     |
# |    time_elapsed       | 193      |
# |    total_timesteps    | 120000   |
# | train/                |          |
# |    entropy_loss       | -3.05    |
# |    explained_variance | 0.768    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5999     |
# |    policy_loss        | 0.0178   |
# |    std                | 0.67     |
# |    value_loss         | 0.000137 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.94     |
# |    ep_rew_mean        | -0.24    |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 620      |
# |    iterations         | 6100     |
# |    time_elapsed       | 196      |
# |    total_timesteps    | 122000   |
# | train/                |          |
# |    entropy_loss       | -3.03    |
# |    explained_variance | 0.177    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6099     |
# |    policy_loss        | 0.00366  |
# |    std                | 0.665    |
# |    value_loss         | 0.000828 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.93     |
# |    ep_rew_mean        | -0.229   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 621      |
# |    iterations         | 6200     |
# |    time_elapsed       | 199      |
# |    total_timesteps    | 124000   |
# | train/                |          |
# |    entropy_loss       | -3.03    |
# |    explained_variance | 0.88     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6199     |
# |    policy_loss        | 0.0159   |
# |    std                | 0.664    |
# |    value_loss         | 0.000172 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.84     |
# |    ep_rew_mean        | -0.217   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 621      |
# |    iterations         | 6300     |
# |    time_elapsed       | 202      |
# |    total_timesteps    | 126000   |
# | train/                |          |
# |    entropy_loss       | -3       |
# |    explained_variance | 0.624    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6299     |
# |    policy_loss        | -0.0874  |
# |    std                | 0.659    |
# |    value_loss         | 0.00138  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.9      |
# |    ep_rew_mean        | -0.228   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 621      |
# |    iterations         | 6400     |
# |    time_elapsed       | 205      |
# |    total_timesteps    | 128000   |
# | train/                |          |
# |    entropy_loss       | -2.99    |
# |    explained_variance | 0.424    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6399     |
# |    policy_loss        | 0.045    |
# |    std                | 0.657    |
# |    value_loss         | 0.000838 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.93     |
# |    ep_rew_mean        | -0.239   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 621      |
# |    iterations         | 6500     |
# |    time_elapsed       | 209      |
# |    total_timesteps    | 130000   |
# | train/                |          |
# |    entropy_loss       | -2.99    |
# |    explained_variance | 0.645    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6499     |
# |    policy_loss        | -0.0157  |
# |    std                | 0.655    |
# |    value_loss         | 0.000377 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.85     |
# |    ep_rew_mean        | -0.216   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 622      |
# |    iterations         | 6600     |
# |    time_elapsed       | 212      |
# |    total_timesteps    | 132000   |
# | train/                |          |
# |    entropy_loss       | -2.96    |
# |    explained_variance | 0.893    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6599     |
# |    policy_loss        | -0.047   |
# |    std                | 0.649    |
# |    value_loss         | 0.00035  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.9      |
# |    ep_rew_mean        | -0.229   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 622      |
# |    iterations         | 6700     |
# |    time_elapsed       | 215      |
# |    total_timesteps    | 134000   |
# | train/                |          |
# |    entropy_loss       | -2.94    |
# |    explained_variance | -0.556   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6699     |
# |    policy_loss        | 0.233    |
# |    std                | 0.645    |
# |    value_loss         | 0.00735  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.86     |
# |    ep_rew_mean        | -0.224   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 622      |
# |    iterations         | 6800     |
# |    time_elapsed       | 218      |
# |    total_timesteps    | 136000   |
# | train/                |          |
# |    entropy_loss       | -2.92    |
# |    explained_variance | 0.557    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6799     |
# |    policy_loss        | -0.0603  |
# |    std                | 0.64     |
# |    value_loss         | 0.000979 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.67     |
# |    ep_rew_mean        | -0.198   |
# |    success_rate       | 1        |
# ...
# |    iterations         | 47800    |
# |    time_elapsed       | 1505     |
# |    total_timesteps    | 956000   |
# | train/                |          |
# |    entropy_loss       | -0.0299  |
# |    explained_variance | 0.955    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 47799    |
# |    policy_loss        | -0.00284 |
# |    std                | 0.259    |
# |    value_loss         | 0.00025  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.94     |
# |    ep_rew_mean        | -0.226   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 634      |
# |    iterations         | 47900    |
# |    time_elapsed       | 1509     |
# |    total_timesteps    | 958000   |
# | train/                |          |
# |    entropy_loss       | -0.0153  |
# |    explained_variance | 0.694    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 47899    |
# |    policy_loss        | 0.0308   |
# |    std                | 0.258    |
# |    value_loss         | 0.00887  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.81     |
# |    ep_rew_mean        | -0.214   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 634      |
# |    iterations         | 48000    |
# |    time_elapsed       | 1512     |
# |    total_timesteps    | 960000   |
# | train/                |          |
# |    entropy_loss       | -0.023   |
# |    explained_variance | 0.958    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 47999    |
# |    policy_loss        | -0.00951 |
# |    std                | 0.259    |
# |    value_loss         | 0.00742  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.16     |
# |    ep_rew_mean        | -0.247   |
# |    success_rate       | 0.99     |
# | time/                 |          |
# |    fps                | 634      |
# |    iterations         | 48100    |
# |    time_elapsed       | 1515     |
# |    total_timesteps    | 962000   |
# | train/                |          |
# |    entropy_loss       | -0.0152  |
# |    explained_variance | 0.626    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48099    |
# |    policy_loss        | -0.00878 |
# |    std                | 0.258    |
# |    value_loss         | 0.00685  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.66     |
# |    ep_rew_mean        | -0.208   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 634      |
# |    iterations         | 48200    |
# |    time_elapsed       | 1518     |
# |    total_timesteps    | 964000   |
# | train/                |          |
# |    entropy_loss       | -0.0254  |
# |    explained_variance | 0.915    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48199    |
# |    policy_loss        | -0.00795 |
# |    std                | 0.259    |
# |    value_loss         | 0.000918 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.63     |
# |    ep_rew_mean        | -0.203   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 634      |
# |    iterations         | 48300    |
# |    time_elapsed       | 1521     |
# |    total_timesteps    | 966000   |
# | train/                |          |
# |    entropy_loss       | -0.0308  |
# |    explained_variance | 0.962    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48299    |
# |    policy_loss        | -0.00121 |
# |    std                | 0.26     |
# |    value_loss         | 0.000221 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.7      |
# |    ep_rew_mean        | -0.206   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 634      |
# |    iterations         | 48400    |
# |    time_elapsed       | 1524     |
# |    total_timesteps    | 968000   |
# | train/                |          |
# |    entropy_loss       | -0.0374  |
# |    explained_variance | 0.958    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48399    |
# |    policy_loss        | -0.00192 |
# |    std                | 0.26     |
# |    value_loss         | 0.000543 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.8      |
# |    ep_rew_mean        | -0.217   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 634      |
# |    iterations         | 48500    |
# |    time_elapsed       | 1528     |
# |    total_timesteps    | 970000   |
# | train/                |          |
# |    entropy_loss       | -0.0459  |
# |    explained_variance | 0.964    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48499    |
# |    policy_loss        | 0.00533  |
# |    std                | 0.261    |
# |    value_loss         | 0.000356 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.69     |
# |    ep_rew_mean        | -0.209   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 634      |
# |    iterations         | 48600    |
# |    time_elapsed       | 1531     |
# |    total_timesteps    | 972000   |
# | train/                |          |
# |    entropy_loss       | -0.0432  |
# |    explained_variance | 0.98     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48599    |
# |    policy_loss        | -0.00334 |
# |    std                | 0.26     |
# |    value_loss         | 0.000217 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.74     |
# |    ep_rew_mean        | -0.216   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 634      |
# |    iterations         | 48700    |
# |    time_elapsed       | 1534     |
# |    total_timesteps    | 974000   |
# | train/                |          |
# |    entropy_loss       | -0.0441  |
# |    explained_variance | 0.972    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48699    |
# |    policy_loss        | -0.00304 |
# |    std                | 0.261    |
# |    value_loss         | 0.000204 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.98     |
# |    ep_rew_mean        | -0.244   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 634      |
# |    iterations         | 48800    |
# |    time_elapsed       | 1537     |
# |    total_timesteps    | 976000   |
# | train/                |          |
# |    entropy_loss       | -0.023   |
# |    explained_variance | 0.952    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48799    |
# |    policy_loss        | -0.00747 |
# |    std                | 0.258    |
# |    value_loss         | 0.000273 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.72      |
# |    ep_rew_mean        | -0.207    |
# |    success_rate       | 1         |
# | time/                 |           |
# |    fps                | 634       |
# |    iterations         | 48900     |
# |    time_elapsed       | 1540      |
# |    total_timesteps    | 978000    |
# | train/                |           |
# |    entropy_loss       | -0.000476 |
# |    explained_variance | 0.834     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 48899     |
# |    policy_loss        | 0.015     |
# |    std                | 0.257     |
# |    value_loss         | 0.000715  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.66     |
# |    ep_rew_mean        | -0.209   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 634      |
# |    iterations         | 49000    |
# |    time_elapsed       | 1543     |
# |    total_timesteps    | 980000   |
# | train/                |          |
# |    entropy_loss       | 0.0138   |
# |    explained_variance | 0.965    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48999    |
# |    policy_loss        | -0.00277 |
# |    std                | 0.255    |
# |    value_loss         | 0.0002   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.81     |
# |    ep_rew_mean        | -0.217   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 634      |
# |    iterations         | 49100    |
# |    time_elapsed       | 1546     |
# |    total_timesteps    | 982000   |
# | train/                |          |
# |    entropy_loss       | 0.0206   |
# |    explained_variance | 0.425    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49099    |
# |    policy_loss        | 0.00175  |
# |    std                | 0.254    |
# |    value_loss         | 0.00834  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.73     |
# |    ep_rew_mean        | -0.213   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 634      |
# |    iterations         | 49200    |
# |    time_elapsed       | 1549     |
# |    total_timesteps    | 984000   |
# | train/                |          |
# |    entropy_loss       | 0.0331   |
# |    explained_variance | 0.969    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49199    |
# |    policy_loss        | 0.00526  |
# |    std                | 0.254    |
# |    value_loss         | 0.000248 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.88     |
# |    ep_rew_mean        | -0.224   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 634      |
# |    iterations         | 49300    |
# |    time_elapsed       | 1552     |
# |    total_timesteps    | 986000   |
# | train/                |          |
# |    entropy_loss       | 0.0538   |
# |    explained_variance | 0.984    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49299    |
# |    policy_loss        | -0.00755 |
# |    std                | 0.252    |
# |    value_loss         | 0.000204 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.86      |
# |    ep_rew_mean        | -0.229    |
# |    success_rate       | 1         |
# | time/                 |           |
# |    fps                | 634       |
# |    iterations         | 49400     |
# |    time_elapsed       | 1556      |
# |    total_timesteps    | 988000    |
# | train/                |           |
# |    entropy_loss       | 0.0605    |
# |    explained_variance | 0.96      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 49399     |
# |    policy_loss        | -0.000845 |
# |    std                | 0.252     |
# |    value_loss         | 0.000229  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.64     |
# |    ep_rew_mean        | -0.2     |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 634      |
# |    iterations         | 49500    |
# |    time_elapsed       | 1559     |
# |    total_timesteps    | 990000   |
# | train/                |          |
# |    entropy_loss       | 0.0563   |
# |    explained_variance | 0.982    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49499    |
# |    policy_loss        | 0.00178  |
# |    std                | 0.252    |
# |    value_loss         | 7.48e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.67     |
# |    ep_rew_mean        | -0.202   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 634      |
# |    iterations         | 49600    |
# |    time_elapsed       | 1562     |
# |    total_timesteps    | 992000   |
# | train/                |          |
# |    entropy_loss       | 0.0614   |
# |    explained_variance | 0.982    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49599    |
# |    policy_loss        | -0.00269 |
# |    std                | 0.251    |
# |    value_loss         | 7.52e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.66     |
# |    ep_rew_mean        | -0.199   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 634      |
# |    iterations         | 49700    |
# |    time_elapsed       | 1565     |
# |    total_timesteps    | 994000   |
# | train/                |          |
# |    entropy_loss       | 0.0942   |
# |    explained_variance | 0.977    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49699    |
# |    policy_loss        | -0.00049 |
# |    std                | 0.248    |
# |    value_loss         | 0.000139 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.68     |
# |    ep_rew_mean        | -0.201   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 634      |
# |    iterations         | 49800    |
# |    time_elapsed       | 1568     |
# |    total_timesteps    | 996000   |
# | train/                |          |
# |    entropy_loss       | 0.103    |
# |    explained_variance | 0.944    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49799    |
# |    policy_loss        | 0.00493  |
# |    std                | 0.248    |
# |    value_loss         | 0.000276 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.83     |
# |    ep_rew_mean        | -0.217   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 634      |
# |    iterations         | 49900    |
# |    time_elapsed       | 1571     |
# |    total_timesteps    | 998000   |
# | train/                |          |
# |    entropy_loss       | 0.0876   |
# |    explained_variance | 0.83     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49899    |
# |    policy_loss        | 0.00529  |
# |    std                | 0.25     |
# |    value_loss         | 0.00118  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.63      |
# |    ep_rew_mean        | -0.195    |
# |    success_rate       | 1         |
# | time/                 |           |
# |    fps                | 634       |
# |    iterations         | 50000     |
# |    time_elapsed       | 1574      |
# |    total_timesteps    | 1000000   |
# | train/                |           |
# |    entropy_loss       | 0.116     |
# |    explained_variance | 0.928     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 49999     |
# |    policy_loss        | -0.000451 |
# |    std                | 0.247     |
# |    value_loss         | 0.000453  |
# -------------------------------------

# %%
# Save the model and  VecNormalize statistics when saving the agent
model.save("a2c-PandaReachDense-v3")
env.save("vec_normalize.pkl")

# %% [markdown]
# ### Evaluate the agent 📈
# - Now that's our  agent is trained, we need to **check its performance**.
# - Stable-Baselines3 provides a method to do that: `evaluate_policy`

# %%
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize

# Load the saved statistics
eval_env = DummyVecEnv([lambda: gym.make("PandaReachDense-v3")])
eval_env = VecNormalize.load("vec_normalize.pkl", eval_env)

# We need to override the render_mode
eval_env.render_mode = "rgb_array"

#  do not update them at test time
eval_env.training = False
# reward normalization is not needed at test time
eval_env.norm_reward = False

# Load the agent
model = A2C.load("a2c-PandaReachDense-v3")

mean_reward, std_reward = evaluate_policy(model, eval_env)

print(f"Mean reward = {mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886
# Mean reward = -0.26 +/- 0.12
# /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(

# %% [markdown]
# ### Publish your trained model on the Hub 🔥
# Now that we saw we got good results after the training, we can publish our trained model on the Hub with one line of code.
#
# 📚 The libraries documentation 👉 https://github.com/huggingface/huggingface_sb3/tree/main#hugging-face--x-stable-baselines3-v20

# %% [markdown]
# By using `package_to_hub`, as we already mentionned in the former units, **you evaluate, record a replay, generate a model card of your agent and push it to the hub**.
#
# This way:
# - You can **showcase our work** 🔥
# - You can **visualize your agent playing** 👀
# - You can **share with the community an agent that others can use** 💾
# - You can **access a leaderboard 🏆 to see how well your agent is performing compared to your classmates** 👉 https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard

# %% [markdown]
# To be able to share your model with the community there are three more steps to follow:
#
# 1️⃣ (If it's not already done) create an account to HF ➡ https://huggingface.co/join
#
# 2️⃣ Sign in and then, you need to store your authentication token from the Hugging Face website.
# - Create a new token (https://huggingface.co/settings/tokens) **with write role**
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/create-token.jpg" alt="Create HF Token">
#
# - Copy the token
# - Run the cell below and paste the token

# %%
notebook_login()
# !git config --global credential.helper store

# %% [markdown]
# If you don't want to use a Google Colab or a Jupyter Notebook, you need to use this command instead: `huggingface-cli login`

# %% [markdown]
# 3️⃣ We're now ready to push our trained agent to the 🤗 Hub 🔥 using `package_to_hub()` function

# %% [markdown]
# For this environment, **running this cell can take approximately 10min**

# %%
from huggingface_sb3 import package_to_hub

package_to_hub(
    model=model,
    model_name=f"a2c-{env_id}",
    model_architecture="A2C",
    env_id=env_id,
    eval_env=eval_env,
    repo_id=f"stalaei/DeepRL-a2c-{env_id}", # Change the username
    commit_message="Initial commit",
)
# Out:
# ℹ This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to 1min.
# This is a work in progress: if you encounter a bug, please open an issue.
# /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Saving video to /tmp/tmpq8l7yqem/-step-0-to-step-1000.mp4
# MoviePy - Building video /tmp/tmpq8l7yqem/-step-0-to-step-1000.mp4.
# MoviePy - Writing video /tmp/tmpq8l7yqem/-step-0-to-step-1000.mp4
# MoviePy - Done !
# MoviePy - video ready /tmp/tmpq8l7yqem/-step-0-to-step-1000.mp4
# ✘ 'DummyVecEnv' object has no attribute 'video_recorder'
# ✘ We are unable to generate a replay of your agent, the package_to_hub
# process continues
# ✘ Please open an issue at
# https://github.com/huggingface/huggingface_sb3/issues
# ℹ Pushing repo stalaei/DeepRL-a2c-PandaReachDense-v3 to the Hugging
# Face Hub
# policy.pth:   0%|          | 0.00/46.4k [00:00<?, ?B/s]
# pytorch_variables.pth:   0%|          | 0.00/864 [00:00<?, ?B/s]
# a2c-PandaReachDense-v3.zip:   0%|          | 0.00/114k [00:00<?, ?B/s]
# Upload 5 LFS files:   0%|          | 0/5 [00:00<?, ?it/s]
# policy.optimizer.pth:   0%|          | 0.00/48.5k [00:00<?, ?B/s]
# vec_normalize.pkl:   0%|          | 0.00/2.64k [00:00<?, ?B/s]
# ℹ Your model is pushed to the Hub. You can view your model here:
# https://huggingface.co/stalaei/DeepRL-a2c-PandaReachDense-v3/tree/main/
# CommitInfo(commit_url='https://huggingface.co/stalaei/DeepRL-a2c-PandaReachDense-v3/commit/278db5ee439286a3befd82082d90365fcb781eb2', commit_message='Initial commit', commit_description='', oid='278db5ee439286a3befd82082d90365fcb781eb2', pr_url=None, repo_url=RepoUrl('https://huggingface.co/stalaei/DeepRL-a2c-PandaReachDense-v3', endpoint='https://huggingface.co', repo_type='model', repo_id='stalaei/DeepRL-a2c-PandaReachDense-v3'), pr_revision=None, pr_num=None)

# %% [markdown]
# ## Some additional challenges 🏆
# The best way to learn **is to try things by your own**! Why not trying  `PandaPickAndPlace-v3`?
#
# If you want to try more advanced tasks for panda-gym, you need to check what was done using **TQC or SAC** (a more sample-efficient algorithm suited for robotics tasks). In real robotics, you'll use a more sample-efficient algorithm for a simple reason: contrary to a simulation **if you move your robotic arm too much, you have a risk of breaking it**.
#
# PandaPickAndPlace-v1 (this model uses the v1 version of the environment): https://huggingface.co/sb3/tqc-PandaPickAndPlace-v1
#
# And don't hesitate to check panda-gym documentation here: https://panda-gym.readthedocs.io/en/latest/usage/train_with_sb3.html
#
# We provide you the steps to train another agent (optional):
#
# 1. Define the environment called "PandaPickAndPlace-v3"
# 2. Make a vectorized environment
# 3. Add a wrapper to normalize the observations and rewards. [Check the documentation](https://stable-baselines3.readthedocs.io/en/master/guide/vec_envs.html#vecnormalize)
# 4. Create the A2C Model (don't forget verbose=1 to print the training logs).
# 5. Train it for 1M Timesteps
# 6. Save the model and  VecNormalize statistics when saving the agent
# 7. Evaluate your agent
# 8. Publish your trained model on the Hub 🔥 with `package_to_hub`

# %% [markdown]
# ### Solution (optional)

# %%
# 1 - 2
env_id = "PandaPickAndPlace-v3"
env = make_vec_env(env_id, n_envs=4)

# 3
env = VecNormalize(env, norm_obs=True, norm_reward=True, clip_obs=10.)

# 4
model = A2C(policy = "MultiInputPolicy",
            env = env,
            verbose=1)
# 5
model.learn(1_000_000)

# %%
# 6
model_name = "a2c-PandaPickAndPlace-v3";
model.save(model_name)
env.save("vec_normalize.pkl")

# 7
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize

# Load the saved statistics
eval_env = DummyVecEnv([lambda: gym.make("PandaPickAndPlace-v3")])
eval_env = VecNormalize.load("vec_normalize.pkl", eval_env)

#  do not update them at test time
eval_env.training = False
# reward normalization is not needed at test time
eval_env.norm_reward = False

# Load the agent
model = A2C.load(model_name)

mean_reward, std_reward = evaluate_policy(model, eval_env)

print(f"Mean reward = {mean_reward:.2f} +/- {std_reward:.2f}")

# 8
package_to_hub(
    model=model,
    model_name=f"a2c-{env_id}",
    model_architecture="A2C",
    env_id=env_id,
    eval_env=eval_env,
    repo_id=f"ThomasSimonini/a2c-{env_id}", # TODO: Change the username
    commit_message="Initial commit",
)

# %% [markdown]
# See you on Unit 7! 🔥
# ## Keep learning, stay awesome 🤗
