# %% [markdown]
# <a href="https://colab.research.google.com/github/huggingface/deep-rl-class/blob/main/notebooks/unit3/unit3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Unit 3: Deep Q-Learning with Atari Games 👾 using RL Baselines3 Zoo
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit4/thumbnail.jpg" alt="Unit 3 Thumbnail">
#
# In this notebook, **you'll train a Deep Q-Learning agent** playing Space Invaders using [RL Baselines3 Zoo](https://github.com/DLR-RM/rl-baselines3-zoo), a training framework based on [Stable-Baselines3](https://stable-baselines3.readthedocs.io/en/master/) that provides scripts for training, evaluating agents, tuning hyperparameters, plotting results and recording videos.
#
# We're using the [RL-Baselines-3 Zoo integration, a vanilla version of Deep Q-Learning](https://stable-baselines3.readthedocs.io/en/master/modules/dqn.html) with no extensions such as Double-DQN, Dueling-DQN, and Prioritized Experience Replay.
#
# ⬇️ Here is an example of what **you will achieve** ⬇️

# %%
# %%html
# <video controls autoplay><source src="https://huggingface.co/ThomasSimonini/ppo-SpaceInvadersNoFrameskip-v4/resolve/main/replay.mp4" type="video/mp4"></video>

# %% [markdown]
# ### 🎮 Environments:
#
# - [SpacesInvadersNoFrameskip-v4](https://gymnasium.farama.org/environments/atari/space_invaders/)
#
# You can see the difference between Space Invaders versions here 👉 https://gymnasium.farama.org/environments/atari/space_invaders/#variants
#
# ### 📚 RL-Library:
#
# - [RL-Baselines3-Zoo](https://github.com/DLR-RM/rl-baselines3-zoo)

# %% [markdown]
# ## Objectives of this notebook 🏆
# At the end of the notebook, you will:
# - Be able to understand deeper **how RL Baselines3 Zoo works**.
# - Be able to **push your trained agent and the code to the Hub** with a nice video replay and an evaluation score 🔥.

# %% [markdown]
# ## This notebook is from Deep Reinforcement Learning Course
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/deep-rl-course-illustration.jpg" alt="Deep RL Course illustration"/>

# %% [markdown]
# In this free course, you will:
#
# - 📖 Study Deep Reinforcement Learning in **theory and practice**.
# - 🧑‍💻 Learn to **use famous Deep RL libraries** such as Stable Baselines3, RL Baselines3 Zoo, CleanRL and Sample Factory 2.0.
# - 🤖 Train **agents in unique environments**
#
# And more check 📚 the syllabus 👉 https://simoninithomas.github.io/deep-rl-course
#
# Don’t forget to **<a href="http://eepurl.com/ic5ZUD">sign up to the course</a>** (we are collecting your email to be able to **send you the links when each Unit is published and give you information about the challenges and updates).**
#
#
# The best way to keep in touch is to join our discord server to exchange with the community and with us 👉🏻 https://discord.gg/ydHrjt3WP5

# %% [markdown]
# ## Prerequisites 🏗️
# Before diving into the notebook, you need to:
#
# 🔲 📚 **[Study Deep Q-Learning by reading Unit 3](https://huggingface.co/deep-rl-course/unit3/introduction)**  🤗

# %% [markdown]
# We're constantly trying to improve our tutorials, so **if you find some issues in this notebook**, please [open an issue on the Github Repo](https://github.com/huggingface/deep-rl-class/issues).

# %% [markdown]
# # Let's train a Deep Q-Learning agent playing Atari' Space Invaders 👾 and upload it to the Hub.
#
# We strongly recommend students **to use Google Colab for the hands-on exercises instead of running them on their personal computers**.
#
# By using Google Colab, **you can focus on learning and experimenting without worrying about the technical aspects of setting up your environments**.
#
# To validate this hands-on for the certification process, you need to push your trained model to the Hub and **get a result of >= 200**.
#
# To find your result, go to the leaderboard and find your model, **the result = mean_reward - std of reward**
#
# For more information about the certification process, check this section 👉 https://huggingface.co/deep-rl-course/en/unit0/introduction#certification-process

# %% [markdown]
# ## An advice 💡
# It's better to run this colab in a copy on your Google Drive, so that **if it timeouts** you still have the saved notebook on your Google Drive and do not need to fill everything from scratch.
#
# To do that you can either do `Ctrl + S` or `File > Save a copy in Google Drive.`
#
# Also, we're going to **train it for 90 minutes with 1M timesteps**. By typing `!nvidia-smi` will tell you what GPU you're using.
#
# And if you want to train more such 10 million steps, this will take about 9 hours, potentially resulting in Colab timing out. In that case, I recommend running this on your local computer (or somewhere else). Just click on: `File>Download`.

# %% [markdown]
# ## Set the GPU 💪
# - To **accelerate the agent's training, we'll use a GPU**. To do that, go to `Runtime > Change Runtime type`
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/gpu-step1.jpg" alt="GPU Step 1">

# %% [markdown]
# - `Hardware Accelerator > GPU`
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/gpu-step2.jpg" alt="GPU Step 2">

# %% [markdown]
# # Install RL-Baselines3 Zoo and its dependencies 📚
#
# If you see `ERROR: pip's dependency resolver does not currently take into account all the packages that are installed.` **this is normal and it's not a critical error** there's a conflict of version. But the packages we need are installed.

# %%
# !pip install git+https://github.com/DLR-RM/rl-baselines3-zoo
# Out:
# Collecting git+https://github.com/DLR-RM/rl-baselines3-zoo
#   Cloning https://github.com/DLR-RM/rl-baselines3-zoo to /tmp/pip-req-build-q3ks4v9s
#   Running command git clone --filter=blob:none --quiet https://github.com/DLR-RM/rl-baselines3-zoo /tmp/pip-req-build-q3ks4v9s
#   Resolved https://github.com/DLR-RM/rl-baselines3-zoo to commit 325ef5dafe46e483ce9d727d2851aff18b70db7c
#   Running command git submodule update --init --recursive -q
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: sb3_contrib<3.0,>=2.6.0 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from rl_zoo3==2.6.0) (2.6.0)
# Requirement already satisfied: gymnasium<1.2.0,>=0.29.1 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from rl_zoo3==2.6.0) (1.1.1)
# Requirement already satisfied: huggingface_sb3<4.0,>=3.0 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from rl_zoo3==2.6.0) (3.0)
# Requirement already satisfied: tqdm in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from rl_zoo3==2.6.0) (4.67.1)
# Requirement already satisfied: rich in /home/stalaei/.local/lib/python3.10/site-packages (from rl_zoo3==2.6.0) (13.7.0)
# Requirement already satisfied: optuna>=3.0 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from rl_zoo3==2.6.0) (4.2.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from rl_zoo3==2.6.0) (6.0.2)
# Requirement already satisfied: pytablewriter~=1.2 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from rl_zoo3==2.6.0) (1.2.1)
# Requirement already satisfied: shimmy~=2.0 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from rl_zoo3==2.6.0) (2.0.0)
# Requirement already satisfied: numpy>=1.21.0 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from gymnasium<1.2.0,>=0.29.1->rl_zoo3==2.6.0) (2.2.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from gymnasium<1.2.0,>=0.29.1->rl_zoo3==2.6.0) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from gymnasium<1.2.0,>=0.29.1->rl_zoo3==2.6.0) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from gymnasium<1.2.0,>=0.29.1->rl_zoo3==2.6.0) (0.0.4)
# Requirement already satisfied: huggingface-hub~=0.8 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from huggingface_sb3<4.0,>=3.0->rl_zoo3==2.6.0) (0.29.3)
# Requirement already satisfied: wasabi in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from huggingface_sb3<4.0,>=3.0->rl_zoo3==2.6.0) (1.1.3)
# Requirement already satisfied: alembic>=1.5.0 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from optuna>=3.0->rl_zoo3==2.6.0) (1.15.1)
# Requirement already satisfied: colorlog in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from optuna>=3.0->rl_zoo3==2.6.0) (6.9.0)
# Requirement already satisfied: packaging>=20.0 in /home/stalaei/.local/lib/python3.10/site-packages (from optuna>=3.0->rl_zoo3==2.6.0) (23.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from optuna>=3.0->rl_zoo3==2.6.0) (2.0.40)
# Requirement already satisfied: setuptools>=38.3.0 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from pytablewriter~=1.2->rl_zoo3==2.6.0) (75.8.0)
# Requirement already satisfied: DataProperty<2,>=1.1.0 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from pytablewriter~=1.2->rl_zoo3==2.6.0) (1.1.0)
# Requirement already satisfied: mbstrdecoder<2,>=1.0.0 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from pytablewriter~=1.2->rl_zoo3==2.6.0) (1.1.4)
# Requirement already satisfied: pathvalidate<4,>=2.3.0 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from pytablewriter~=1.2->rl_zoo3==2.6.0) (3.2.3)
# Requirement already satisfied: tabledata<2,>=1.3.1 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from pytablewriter~=1.2->rl_zoo3==2.6.0) (1.3.4)
# Requirement already satisfied: tcolorpy<1,>=0.0.5 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from pytablewriter~=1.2->rl_zoo3==2.6.0) (0.1.7)
# Requirement already satisfied: typepy<2,>=1.3.2 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3==2.6.0) (1.3.4)
# Requirement already satisfied: stable_baselines3<3.0,>=2.6.0 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from sb3_contrib<3.0,>=2.6.0->rl_zoo3==2.6.0) (2.6.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/stalaei/.local/lib/python3.10/site-packages (from rich->rl_zoo3==2.6.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/stalaei/.local/lib/python3.10/site-packages (from rich->rl_zoo3==2.6.0) (2.17.2)
# Requirement already satisfied: Mako in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from alembic>=1.5.0->optuna>=3.0->rl_zoo3==2.6.0) (1.3.9)
# Requirement already satisfied: filelock in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.6.0) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.6.0) (2025.3.0)
# Requirement already satisfied: requests in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.6.0) (2.32.3)
# Requirement already satisfied: mdurl~=0.1 in /home/stalaei/.local/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->rl_zoo3==2.6.0) (0.1.2)
# Requirement already satisfied: chardet<6,>=3.0.4 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from mbstrdecoder<2,>=1.0.0->pytablewriter~=1.2->rl_zoo3==2.6.0) (5.2.0)
# Requirement already satisfied: greenlet>=1 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from sqlalchemy>=1.4.2->optuna>=3.0->rl_zoo3==2.6.0) (3.1.1)
# Requirement already satisfied: torch<3.0,>=2.3 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from stable_baselines3<3.0,>=2.6.0->sb3_contrib<3.0,>=2.6.0->rl_zoo3==2.6.0) (2.6.0)
# Requirement already satisfied: pandas in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from stable_baselines3<3.0,>=2.6.0->sb3_contrib<3.0,>=2.6.0->rl_zoo3==2.6.0) (2.2.3)
# Requirement already satisfied: matplotlib in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from stable_baselines3<3.0,>=2.6.0->sb3_contrib<3.0,>=2.6.0->rl_zoo3==2.6.0) (3.10.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.0 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3==2.6.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2018.9 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3==2.6.0) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.8.0->typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3==2.6.0) (1.17.0)
# Requirement already satisfied: networkx in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3_contrib<3.0,>=2.6.0->rl_zoo3==2.6.0) (3.4.2)
# Requirement already satisfied: jinja2 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3_contrib<3.0,>=2.6.0->rl_zoo3==2.6.0) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3_contrib<3.0,>=2.6.0->rl_zoo3==2.6.0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3_contrib<3.0,>=2.6.0->rl_zoo3==2.6.0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3_contrib<3.0,>=2.6.0->rl_zoo3==2.6.0) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3_contrib<3.0,>=2.6.0->rl_zoo3==2.6.0) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3_contrib<3.0,>=2.6.0->rl_zoo3==2.6.0) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3_contrib<3.0,>=2.6.0->rl_zoo3==2.6.0) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3_contrib<3.0,>=2.6.0->rl_zoo3==2.6.0) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3_contrib<3.0,>=2.6.0->rl_zoo3==2.6.0) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3_contrib<3.0,>=2.6.0->rl_zoo3==2.6.0) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3_contrib<3.0,>=2.6.0->rl_zoo3==2.6.0) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3_contrib<3.0,>=2.6.0->rl_zoo3==2.6.0) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3_contrib<3.0,>=2.6.0->rl_zoo3==2.6.0) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3_contrib<3.0,>=2.6.0->rl_zoo3==2.6.0) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3_contrib<3.0,>=2.6.0->rl_zoo3==2.6.0) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3_contrib<3.0,>=2.6.0->rl_zoo3==2.6.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from sympy==1.13.1->torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3_contrib<3.0,>=2.6.0->rl_zoo3==2.6.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from Mako->alembic>=1.5.0->optuna>=3.0->rl_zoo3==2.6.0) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from matplotlib->stable_baselines3<3.0,>=2.6.0->sb3_contrib<3.0,>=2.6.0->rl_zoo3==2.6.0) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from matplotlib->stable_baselines3<3.0,>=2.6.0->sb3_contrib<3.0,>=2.6.0->rl_zoo3==2.6.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from matplotlib->stable_baselines3<3.0,>=2.6.0->sb3_contrib<3.0,>=2.6.0->rl_zoo3==2.6.0) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from matplotlib->stable_baselines3<3.0,>=2.6.0->sb3_contrib<3.0,>=2.6.0->rl_zoo3==2.6.0) (1.4.8)
# Requirement already satisfied: pillow>=8 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from matplotlib->stable_baselines3<3.0,>=2.6.0->sb3_contrib<3.0,>=2.6.0->rl_zoo3==2.6.0) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from matplotlib->stable_baselines3<3.0,>=2.6.0->sb3_contrib<3.0,>=2.6.0->rl_zoo3==2.6.0) (3.2.3)
# Requirement already satisfied: tzdata>=2022.7 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from pandas->stable_baselines3<3.0,>=2.6.0->sb3_contrib<3.0,>=2.6.0->rl_zoo3==2.6.0) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from requests->huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.6.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from requests->huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.6.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from requests->huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.6.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from requests->huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.6.0) (2025.1.31)
#
# [notice] A new release of pip is available: 23.3.2 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
# !apt-get install swig cmake ffmpeg
# Out:
# E: Could not open lock file /var/lib/dpkg/lock-frontend - open (13: Permission denied)
# E: Unable to acquire the dpkg frontend lock (/var/lib/dpkg/lock-frontend), are you root?

# %% [markdown]
# To be able to use Atari games in Gymnasium we need to install atari package. And accept-rom-license to download the rom files (games files).

# %%
# !pip install gymnasium[atari]
# !pip install gymnasium[accept-rom-license]
# Out:
# Requirement already satisfied: gymnasium[atari] in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (1.1.1)
# Requirement already satisfied: numpy>=1.21.0 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from gymnasium[atari]) (2.2.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from gymnasium[atari]) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from gymnasium[atari]) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from gymnasium[atari]) (0.0.4)
# Requirement already satisfied: ale_py>=0.9 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from gymnasium[atari]) (0.10.2)
#
# [notice] A new release of pip is available: 23.3.2 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: gymnasium[accept-rom-license] in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (1.1.1)
# WARNING: gymnasium 1.1.1 does not provide the extra 'accept-rom-license'
# Requirement already satisfied: numpy>=1.21.0 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from gymnasium[accept-rom-license]) (2.2.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from gymnasium[accept-rom-license]) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from gymnasium[accept-rom-license]) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from gymnasium[accept-rom-license]) (0.0.4)
#
# [notice] A new release of pip is available: 23.3.2 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## Create a virtual display 🔽
#
# During the notebook, we'll need to generate a replay video. To do so, with colab, **we need to have a virtual screen to be able to render the environment** (and thus record the frames).
#
# Hence the following cell will install the librairies and create and run a virtual screen 🖥

# %%
# %%capture
# !apt install python-opengl
# !apt install xvfb
# !pip3 install pyvirtualdisplay

# %%
# Virtual display
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %% [markdown]
# ## Train our Deep Q-Learning Agent to Play Space Invaders 👾
#
# To train an agent with RL-Baselines3-Zoo, we just need to do two things:
#
# 1. Create a hyperparameter config file that will contain our training hyperparameters called `dqn.yml`.
#
# This is a template example:
#
# ```
# SpaceInvadersNoFrameskip-v4:
#   env_wrapper:
#     - stable_baselines3.common.atari_wrappers.AtariWrapper
#   frame_stack: 4
#   policy: 'CnnPolicy'
#   n_timesteps: !!float 1e6
#   buffer_size: 100000
#   learning_rate: !!float 1e-4
#   batch_size: 32
#   learning_starts: 100000
#   target_update_interval: 1000
#   train_freq: 4
#   gradient_steps: 1
#   exploration_fraction: 0.1
#   exploration_final_eps: 0.01
#   # If True, you need to deactivate handle_timeout_termination
#   # in the replay_buffer_kwargs
#   optimize_memory_usage: False
# ```

# %% [markdown]
# Here we see that:
# - We use the `Atari Wrapper` that preprocess the input (Frame reduction ,grayscale, stack 4 frames)
# - We use `CnnPolicy`, since we use Convolutional layers to process the frames
# - We train it for 10 million `n_timesteps`
# - Memory (Experience Replay) size is 100000, aka the amount of experience steps you saved to train again your agent with.
#
# 💡 My advice is to **reduce the training timesteps to 1M,** which will take about 90 minutes on a P100. `!nvidia-smi` will tell you what GPU you're using. At 10 million steps, this will take about 9 hours, which could likely result in Colab timing out. I recommend running this on your local computer (or somewhere else). Just click on: `File>Download`.

# %% [markdown]
# In terms of hyperparameters optimization, my advice is to focus on these 3 hyperparameters:
# - `learning_rate`
# - `buffer_size (Experience Memory size)`
# - `batch_size`
#
# As a good practice, you need to **check the documentation to understand what each hyperparameters does**: https://stable-baselines3.readthedocs.io/en/master/modules/dqn.html#parameters

# %% [markdown]
# 2. We start the training and save the models on `logs` folder 📁
#
# - Define the algorithm after `--algo`, where we save the model after `-f` and where the hyperparameter config is after `-c`.

# %%
# !pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.21.2 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from opencv-python) (2.2.4)
# Downloading opencv_python-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (63.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 MB 34.6 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.11.0.86
#
# [notice] A new release of pip is available: 23.3.2 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
# !python -m rl_zoo3.train --algo dqn --env SpaceInvadersNoFrameskip-v4  -f logs/  -c dqn.yml
# Out:
# ========== SpaceInvadersNoFrameskip-v4 ==========
# Seed: 1944423927
# Loading hyperparameters from: dqn.yml
# Default hyperparameters for environment (ones being tuned will be overridden):
# OrderedDict([('batch_size', 32),
#              ('buffer_size', 100000),
#              ('env_wrapper',
#               ['stable_baselines3.common.atari_wrappers.AtariWrapper']),
#              ('exploration_final_eps', 0.01),
#              ('exploration_fraction', 0.1),
#              ('frame_stack', 4),
#              ('gradient_steps', 1),
#              ('learning_rate', 0.0001),
#              ('learning_starts', 100000),
#              ('n_timesteps', 1000000.0),
#              ('optimize_memory_usage', False),
#              ('policy', 'CnnPolicy'),
#              ('target_update_interval', 1000),
#              ('train_freq', 4)])
# Using 1 environments
# Creating test environment
# A.L.E: Arcade Learning Environment (version 0.10.2+c9d4b19)
# [Powered by Stella]
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Using cuda device
# Log path: logs//dqn/SpaceInvadersNoFrameskip-v4_4
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.53e+03 |
# |    ep_rew_mean      | 130      |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 884      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 818      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.55e+03 |
# |    ep_rew_mean      | 185      |
# |    exploration_rate | 0.983    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 947      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1765     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.54e+03 |
# |    ep_rew_mean      | 241      |
# |    exploration_rate | 0.975    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 967      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2497     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.4e+03  |
# |    ep_rew_mean      | 220      |
# |    exploration_rate | 0.967    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 981      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3302     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.5e+03  |
# |    ep_rew_mean      | 213      |
# |    exploration_rate | 0.961    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 988      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3917     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.51e+03 |
# |    ep_rew_mean      | 202      |
# |    exploration_rate | 0.951    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 1000     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4918     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.37e+03 |
# |    ep_rew_mean      | 186      |
# |    exploration_rate | 0.947    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 1003     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 5400     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.29e+03 |
# |    ep_rew_mean      | 179      |
# |    exploration_rate | 0.941    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 1006     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 5919     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.18e+03 |
# |    ep_rew_mean      | 165      |
# |    exploration_rate | 0.936    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 1007     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 6415     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.15e+03 |
# |    ep_rew_mean      | 159      |
# |    exploration_rate | 0.931    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 1008     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 6975     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.924    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 1011     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 7700     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 158      |
# |    exploration_rate | 0.92     |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 1011     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 8092     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.914    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 1012     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 8737     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.909    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 1013     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 9235     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.96e+03 |
# |    ep_rew_mean      | 144      |
# |    exploration_rate | 0.905    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 1012     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 9590     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.93e+03 |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.902    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 1012     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 9949     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.93e+03 |
# |    ep_rew_mean      | 140      |
# |    exploration_rate | 0.892    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 1015     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 10937    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.95e+03 |
# |    ep_rew_mean      | 142      |
# |    exploration_rate | 0.887    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 1014     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 11424    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 147      |
# |    exploration_rate | 0.877    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 1017     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 12424    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 145      |
# |    exploration_rate | 0.873    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 1017     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 12850    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 144      |
# |    exploration_rate | 0.865    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 1018     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 13631    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.98e+03 |
# |    ep_rew_mean      | 142      |
# |    exploration_rate | 0.859    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 1018     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 14230    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2e+03    |
# |    ep_rew_mean      | 143      |
# |    exploration_rate | 0.852    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 1019     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 14964    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 148      |
# |    exploration_rate | 0.844    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 1022     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 15766    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 148      |
# |    exploration_rate | 0.837    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 1024     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 16417    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 145      |
# |    exploration_rate | 0.834    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 1025     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 16756    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.96e+03 |
# |    ep_rew_mean      | 143      |
# |    exploration_rate | 0.83     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 1025     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 17186    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.94e+03 |
# |    ep_rew_mean      | 141      |
# |    exploration_rate | 0.823    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 1026     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 17914    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.96e+03 |
# |    ep_rew_mean      | 145      |
# |    exploration_rate | 0.815    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 1029     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 18687    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.805    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 1030     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 19697    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.01e+03 |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.8      |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 1030     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 20245    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2e+03    |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.794    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 1030     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 20779    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2e+03    |
# |    ep_rew_mean      | 147      |
# |    exploration_rate | 0.788    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 1031     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 21446    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.01e+03 |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.78     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 1031     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 22224    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2e+03    |
# |    ep_rew_mean      | 148      |
# |    exploration_rate | 0.774    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 1031     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 22793    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.763    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 1033     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 23924    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 155      |
# |    exploration_rate | 0.754    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 1033     |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 24830    |
# ----------------------------------
# Eval num_timesteps=25000, episode_reward=158.00 +/- 51.24
# Episode length: 2246.60 +/- 282.67
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 2.25e+03 |
# |    mean_reward      | 158      |
# | rollout/            |          |
# |    exploration_rate | 0.753    |
# | time/               |          |
# |    total_timesteps  | 25000    |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 157      |
# |    exploration_rate | 0.746    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 898      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 25668    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.741    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 900      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 26168    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.734    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 903      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 26853    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.727    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 906      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 27584    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.721    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 908      |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 28229    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.714    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 911      |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 28879    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 148      |
# |    exploration_rate | 0.71     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 912      |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 29285    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 148      |
# |    exploration_rate | 0.704    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 915      |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 29948    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 146      |
# |    exploration_rate | 0.698    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 917      |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 30490    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 146      |
# |    exploration_rate | 0.692    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 920      |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 31107    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 145      |
# |    exploration_rate | 0.684    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 923      |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 31913    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 146      |
# |    exploration_rate | 0.677    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 926      |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 32578    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 144      |
# |    exploration_rate | 0.673    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 928      |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 33051    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 144      |
# |    exploration_rate | 0.667    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 930      |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 33655    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 144      |
# |    exploration_rate | 0.66     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 932      |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 34368    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 147      |
# |    exploration_rate | 0.651    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 935      |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 35234    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 146      |
# |    exploration_rate | 0.645    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 936      |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 35827    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 147      |
# |    exploration_rate | 0.634    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 939      |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 36925    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 148      |
# |    exploration_rate | 0.628    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 941      |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 37588    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 147      |
# |    exploration_rate | 0.62     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 943      |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 38372    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 146      |
# |    exploration_rate | 0.616    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 944      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 38793    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 145      |
# |    exploration_rate | 0.61     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 945      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 39376    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 144      |
# |    exploration_rate | 0.604    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 946      |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 39976    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 143      |
# |    exploration_rate | 0.6      |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 947      |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 40410    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 143      |
# |    exploration_rate | 0.593    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 948      |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 41078    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 142      |
# |    exploration_rate | 0.587    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 949      |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 41679    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 141      |
# |    exploration_rate | 0.581    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 950      |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 42371    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 140      |
# |    exploration_rate | 0.575    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 950      |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 42882    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.57     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 951      |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 43453    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.562    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 953      |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 44260    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.55     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 955      |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 45409    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 141      |
# |    exploration_rate | 0.547    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 956      |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 45768    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 142      |
# |    exploration_rate | 0.537    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 957      |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 46720    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 142      |
# |    exploration_rate | 0.531    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 958      |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 47341    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 141      |
# |    exploration_rate | 0.526    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 958      |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 47886    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 141      |
# |    exploration_rate | 0.519    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 960      |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 48611    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 141      |
# |    exploration_rate | 0.512    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 961      |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 49276    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 141      |
# |    exploration_rate | 0.507    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 962      |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 49805    |
# ----------------------------------
# Eval num_timesteps=50000, episode_reward=178.00 +/- 29.77
# Episode length: 2517.80 +/- 51.17
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 2.52e+03 |
# |    mean_reward      | 178      |
# | rollout/            |          |
# |    exploration_rate | 0.505    |
# | time/               |          |
# |    total_timesteps  | 50000    |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 141      |
# |    exploration_rate | 0.499    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 894      |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 50605    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 140      |
# |    exploration_rate | 0.495    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 895      |
# |    time_elapsed     | 57       |
# |    total_timesteps  | 51052    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.01e+03 |
# |    ep_rew_mean      | 136      |
# |    exploration_rate | 0.488    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 896      |
# |    time_elapsed     | 57       |
# |    total_timesteps  | 51684    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 136      |
# |    exploration_rate | 0.481    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 898      |
# |    time_elapsed     | 58       |
# |    total_timesteps  | 52410    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.01e+03 |
# |    ep_rew_mean      | 135      |
# |    exploration_rate | 0.474    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 900      |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 53114    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2e+03    |
# |    ep_rew_mean      | 134      |
# |    exploration_rate | 0.468    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 901      |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 53692    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2e+03    |
# |    ep_rew_mean      | 134      |
# |    exploration_rate | 0.462    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 902      |
# |    time_elapsed     | 60       |
# |    total_timesteps  | 54324    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2e+03    |
# |    ep_rew_mean      | 133      |
# |    exploration_rate | 0.457    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 902      |
# |    time_elapsed     | 60       |
# |    total_timesteps  | 54889    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2e+03    |
# |    ep_rew_mean      | 134      |
# |    exploration_rate | 0.453    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 903      |
# |    time_elapsed     | 61       |
# |    total_timesteps  | 55263    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.01e+03 |
# |    ep_rew_mean      | 136      |
# |    exploration_rate | 0.445    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 904      |
# |    time_elapsed     | 61       |
# |    total_timesteps  | 56048    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 136      |
# |    exploration_rate | 0.437    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 906      |
# |    time_elapsed     | 62       |
# |    total_timesteps  | 56841    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 135      |
# |    exploration_rate | 0.431    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 907      |
# |    time_elapsed     | 63       |
# |    total_timesteps  | 57497    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 134      |
# |    exploration_rate | 0.425    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 908      |
# |    time_elapsed     | 63       |
# |    total_timesteps  | 58035    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 137      |
# |    exploration_rate | 0.415    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 910      |
# |    time_elapsed     | 64       |
# |    total_timesteps  | 59044    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.409    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 911      |
# |    time_elapsed     | 65       |
# |    total_timesteps  | 59658    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.403    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 911      |
# |    time_elapsed     | 66       |
# |    total_timesteps  | 60286    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.396    |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 913      |
# |    time_elapsed     | 66       |
# |    total_timesteps  | 61015    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 140      |
# |    exploration_rate | 0.386    |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 915      |
# |    time_elapsed     | 67       |
# |    total_timesteps  | 62048    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.379    |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 917      |
# |    time_elapsed     | 68       |
# |    total_timesteps  | 62769    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 140      |
# |    exploration_rate | 0.372    |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 918      |
# |    time_elapsed     | 69       |
# |    total_timesteps  | 63460    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 141      |
# |    exploration_rate | 0.365    |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 919      |
# |    time_elapsed     | 69       |
# |    total_timesteps  | 64100    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 143      |
# |    exploration_rate | 0.355    |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 921      |
# |    time_elapsed     | 70       |
# |    total_timesteps  | 65179    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 145      |
# |    exploration_rate | 0.349    |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 922      |
# |    time_elapsed     | 71       |
# |    total_timesteps  | 65765    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 145      |
# |    exploration_rate | 0.339    |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 923      |
# |    time_elapsed     | 72       |
# |    total_timesteps  | 66783    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 145      |
# |    exploration_rate | 0.327    |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 925      |
# |    time_elapsed     | 73       |
# |    total_timesteps  | 67959    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 147      |
# |    exploration_rate | 0.319    |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 926      |
# |    time_elapsed     | 74       |
# |    total_timesteps  | 68761    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.14e+03 |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.312    |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 927      |
# |    time_elapsed     | 74       |
# |    total_timesteps  | 69515    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.15e+03 |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.305    |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 928      |
# |    time_elapsed     | 75       |
# |    total_timesteps  | 70251    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.14e+03 |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.298    |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 929      |
# |    time_elapsed     | 76       |
# |    total_timesteps  | 70953    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 146      |
# |    exploration_rate | 0.292    |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 930      |
# |    time_elapsed     | 76       |
# |    total_timesteps  | 71553    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 145      |
# |    exploration_rate | 0.285    |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 931      |
# |    time_elapsed     | 77       |
# |    total_timesteps  | 72246    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.13e+03 |
# |    ep_rew_mean      | 145      |
# |    exploration_rate | 0.279    |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 931      |
# |    time_elapsed     | 78       |
# |    total_timesteps  | 72840    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 146      |
# |    exploration_rate | 0.274    |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 932      |
# |    time_elapsed     | 78       |
# |    total_timesteps  | 73352    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 144      |
# |    exploration_rate | 0.269    |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 932      |
# |    time_elapsed     | 79       |
# |    total_timesteps  | 73866    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 145      |
# |    exploration_rate | 0.261    |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 933      |
# |    time_elapsed     | 79       |
# |    total_timesteps  | 74636    |
# ----------------------------------
# Eval num_timesteps=75000, episode_reward=183.00 +/- 14.70
# Episode length: 2479.00 +/- 44.09
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 2.48e+03 |
# |    mean_reward      | 183      |
# | rollout/            |          |
# |    exploration_rate | 0.258    |
# | time/               |          |
# |    total_timesteps  | 75000    |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 142      |
# |    exploration_rate | 0.256    |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 880      |
# |    time_elapsed     | 85       |
# |    total_timesteps  | 75144    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 142      |
# |    exploration_rate | 0.25     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 881      |
# |    time_elapsed     | 85       |
# |    total_timesteps  | 75803    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 140      |
# |    exploration_rate | 0.245    |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 882      |
# |    time_elapsed     | 86       |
# |    total_timesteps  | 76255    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 141      |
# |    exploration_rate | 0.239    |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 883      |
# |    time_elapsed     | 87       |
# |    total_timesteps  | 76908    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 142      |
# |    exploration_rate | 0.23     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 884      |
# |    time_elapsed     | 87       |
# |    total_timesteps  | 77786    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 143      |
# |    exploration_rate | 0.225    |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 884      |
# |    time_elapsed     | 88       |
# |    total_timesteps  | 78274    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 145      |
# |    exploration_rate | 0.216    |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 886      |
# |    time_elapsed     | 89       |
# |    total_timesteps  | 79204    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 145      |
# |    exploration_rate | 0.209    |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 886      |
# |    time_elapsed     | 90       |
# |    total_timesteps  | 79867    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 145      |
# ...
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0247   |
# |    n_updates        | 214616   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.14e+03 |
# |    ep_rew_mean      | 619      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4084     |
# |    fps              | 352      |
# |    time_elapsed     | 2725     |
# |    total_timesteps  | 960060   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0105   |
# |    n_updates        | 215014   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.13e+03 |
# |    ep_rew_mean      | 619      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4088     |
# |    fps              | 352      |
# |    time_elapsed     | 2728     |
# |    total_timesteps  | 960979   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0272   |
# |    n_updates        | 215244   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.09e+03 |
# |    ep_rew_mean      | 614      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4092     |
# |    fps              | 352      |
# |    time_elapsed     | 2731     |
# |    total_timesteps  | 962292   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0245   |
# |    n_updates        | 215572   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.09e+03 |
# |    ep_rew_mean      | 614      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4096     |
# |    fps              | 352      |
# |    time_elapsed     | 2734     |
# |    total_timesteps  | 963508   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0232   |
# |    n_updates        | 215876   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.08e+03 |
# |    ep_rew_mean      | 617      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4100     |
# |    fps              | 352      |
# |    time_elapsed     | 2739     |
# |    total_timesteps  | 965468   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0216   |
# |    n_updates        | 216366   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.06e+03 |
# |    ep_rew_mean      | 613      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4104     |
# |    fps              | 352      |
# |    time_elapsed     | 2741     |
# |    total_timesteps  | 966172   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0165   |
# |    n_updates        | 216542   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.06e+03 |
# |    ep_rew_mean      | 611      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4108     |
# |    fps              | 352      |
# |    time_elapsed     | 2744     |
# |    total_timesteps  | 967220   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0451   |
# |    n_updates        | 216804   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.12e+03 |
# |    ep_rew_mean      | 619      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4112     |
# |    fps              | 352      |
# |    time_elapsed     | 2751     |
# |    total_timesteps  | 970116   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0123   |
# |    n_updates        | 217528   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.11e+03 |
# |    ep_rew_mean      | 611      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4116     |
# |    fps              | 352      |
# |    time_elapsed     | 2755     |
# |    total_timesteps  | 971454   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0196   |
# |    n_updates        | 217863   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.11e+03 |
# |    ep_rew_mean      | 610      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4120     |
# |    fps              | 352      |
# |    time_elapsed     | 2758     |
# |    total_timesteps  | 972793   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0454   |
# |    n_updates        | 218198   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.11e+03 |
# |    ep_rew_mean      | 610      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4124     |
# |    fps              | 352      |
# |    time_elapsed     | 2762     |
# |    total_timesteps  | 974347   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0267   |
# |    n_updates        | 218586   |
# ----------------------------------
# Eval num_timesteps=975000, episode_reward=602.00 +/- 80.91
# Episode length: 3913.20 +/- 607.24
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.91e+03 |
# |    mean_reward      | 602      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 975000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0102   |
# |    n_updates        | 218749   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.11e+03 |
# |    ep_rew_mean      | 612      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4128     |
# |    fps              | 351      |
# |    time_elapsed     | 2774     |
# |    total_timesteps  | 975795   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0116   |
# |    n_updates        | 218948   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.11e+03 |
# |    ep_rew_mean      | 612      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4132     |
# |    fps              | 351      |
# |    time_elapsed     | 2776     |
# |    total_timesteps  | 976630   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0266   |
# |    n_updates        | 219157   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.08e+03 |
# |    ep_rew_mean      | 605      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4136     |
# |    fps              | 351      |
# |    time_elapsed     | 2778     |
# |    total_timesteps  | 977595   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0327   |
# |    n_updates        | 219398   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.08e+03 |
# |    ep_rew_mean      | 602      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4140     |
# |    fps              | 351      |
# |    time_elapsed     | 2786     |
# |    total_timesteps  | 980346   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0259   |
# |    n_updates        | 220086   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.09e+03 |
# |    ep_rew_mean      | 610      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4144     |
# |    fps              | 351      |
# |    time_elapsed     | 2793     |
# |    total_timesteps  | 983033   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0306   |
# |    n_updates        | 220758   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.09e+03 |
# |    ep_rew_mean      | 610      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4148     |
# |    fps              | 351      |
# |    time_elapsed     | 2798     |
# |    total_timesteps  | 984559   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0239   |
# |    n_updates        | 221139   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.11e+03 |
# |    ep_rew_mean      | 610      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4152     |
# |    fps              | 351      |
# |    time_elapsed     | 2802     |
# |    total_timesteps  | 986152   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0157   |
# |    n_updates        | 221537   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.09e+03 |
# |    ep_rew_mean      | 609      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4156     |
# |    fps              | 351      |
# |    time_elapsed     | 2806     |
# |    total_timesteps  | 987396   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0666   |
# |    n_updates        | 221848   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.07e+03 |
# |    ep_rew_mean      | 605      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4160     |
# |    fps              | 351      |
# |    time_elapsed     | 2808     |
# |    total_timesteps  | 988295   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0183   |
# |    n_updates        | 222073   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.05e+03 |
# |    ep_rew_mean      | 602      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4164     |
# |    fps              | 351      |
# |    time_elapsed     | 2810     |
# |    total_timesteps  | 988997   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.022    |
# |    n_updates        | 222249   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.08e+03 |
# |    ep_rew_mean      | 605      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4168     |
# |    fps              | 351      |
# |    time_elapsed     | 2815     |
# |    total_timesteps  | 990652   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0138   |
# |    n_updates        | 222662   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.08e+03 |
# |    ep_rew_mean      | 605      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4172     |
# |    fps              | 351      |
# |    time_elapsed     | 2819     |
# |    total_timesteps  | 991917   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.027    |
# |    n_updates        | 222979   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.03e+03 |
# |    ep_rew_mean      | 595      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4176     |
# |    fps              | 351      |
# |    time_elapsed     | 2823     |
# |    total_timesteps  | 993559   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0503   |
# |    n_updates        | 223389   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.01e+03 |
# |    ep_rew_mean      | 595      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4180     |
# |    fps              | 351      |
# |    time_elapsed     | 2826     |
# |    total_timesteps  | 994509   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00628  |
# |    n_updates        | 223627   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.01e+03 |
# |    ep_rew_mean      | 598      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4184     |
# |    fps              | 351      |
# |    time_elapsed     | 2834     |
# |    total_timesteps  | 997184   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0196   |
# |    n_updates        | 224295   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.02e+03 |
# |    ep_rew_mean      | 599      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4188     |
# |    fps              | 351      |
# |    time_elapsed     | 2837     |
# |    total_timesteps  | 998242   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0323   |
# |    n_updates        | 224560   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.02e+03 |
# |    ep_rew_mean      | 601      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4192     |
# |    fps              | 351      |
# |    time_elapsed     | 2841     |
# |    total_timesteps  | 999720   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0172   |
# |    n_updates        | 224929   |
# ----------------------------------
# Eval num_timesteps=1000000, episode_reward=642.00 +/- 355.09
# Episode length: 3642.20 +/- 1572.27
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.64e+03 |
# |    mean_reward      | 642      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 1000000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0231   |
# |    n_updates        | 224999   |
# ----------------------------------
# Saving to logs//dqn/SpaceInvadersNoFrameskip-v4_4

# %% [markdown]
# #### Solution

# %%
# !python -m rl_zoo3.train --algo dqn  --env SpaceInvadersNoFrameskip-v4 -f logs/ -c dqn.yml

# %% [markdown]
# ## Let's evaluate our agent 👀
# - RL-Baselines3-Zoo provides `enjoy.py`, a python script to evaluate our agent. In most RL libraries, we call the evaluation script `enjoy.py`.
# - Let's evaluate it for 5000 timesteps 🔥

# %%
# !python -m rl_zoo3.enjoy  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --no-render  --n-timesteps 5000  --folder logs/
# Out:
# Loading latest experiment, id=4
# Loading logs/dqn/SpaceInvadersNoFrameskip-v4_4/SpaceInvadersNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.10.2+c9d4b19)
# [Powered by Stella]
# Stacking 4 frames
# Atari Episode Score: 700.00
# Atari Episode Length 4617
# Atari Episode Score: 330.00
# Atari Episode Length 2369
# Atari Episode Score: 845.00
# Atari Episode Length 6131
# Atari Episode Score: 295.00
# Atari Episode Length 2284
# Atari Episode Score: 340.00
# Atari Episode Length 2899

# %% [markdown]
# #### Solution

# %%
# !python -m rl_zoo3.enjoy  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --no-render  --n-timesteps 5000  --folder logs/

# %% [markdown]
# ## Publish our trained model on the Hub 🚀
# Now that we saw we got good results after the training, we can publish our trained model on the hub 🤗 with one line of code.
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit3/space-invaders-model.gif" alt="Space Invaders model">

# %% [markdown]
# By using `rl_zoo3.push_to_hub` **you evaluate, record a replay, generate a model card of your agent and push it to the hub**.
#
# This way:
# - You can **showcase our work** 🔥
# - You can **visualize your agent playing** 👀
# - You can **share with the community an agent that others can use** 💾
# - You can **access a leaderboard 🏆 to see how well your agent is performing compared to your classmates** 👉  https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard

# %% [markdown]
# To be able to share your model with the community there are three more steps to follow:
#
# 1️⃣ (If it's not already done) create an account to HF ➡ https://huggingface.co/join
#
# 2️⃣ Sign in and then, you need to store your authentication token from the Hugging Face website.
# - Create a new token (https://huggingface.co/settings/tokens) **with write role**
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/create-token.jpg" alt="Create HF Token">

# %% [markdown]
# - Copy the token
# - Run the cell below and past the token

# %%
import os
from dotenv import load_dotenv
from huggingface_hub import login # To log to our Hugging Face account to be able to upload models to the Hub.

# Load token from .env file
load_dotenv()
hf_token = os.getenv("HF_TOKEN")

# Login with the token
login(token=hf_token)
# !git config --global credential.helper store
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.

# %% [markdown]
# If you don't want to use a Google Colab or a Jupyter Notebook, you need to use this command instead: `huggingface-cli login`

# %% [markdown]
# 3️⃣ We're now ready to push our trained agent to the 🤗 Hub 🔥

# %% [markdown]
# Let's run push_to_hub.py file to upload our trained agent to the Hub.
#
# `--repo-name `: The name of the repo
#
# `-orga`: Your Hugging Face username
#
# `-f`: Where the trained model folder is (in our case `logs`)
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit3/select-id.png" alt="Select Id">

# %%
# !pip install 'gymnasium[other]'
# Out:
# Requirement already satisfied: gymnasium[other] in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (1.1.1)
# Requirement already satisfied: numpy>=1.21.0 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from gymnasium[other]) (2.2.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from gymnasium[other]) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from gymnasium[other]) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from gymnasium[other]) (0.0.4)
# Collecting moviepy>=1.0.0 (from gymnasium[other])
#   Downloading moviepy-2.1.2-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: matplotlib>=3.0 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from gymnasium[other]) (3.10.1)
# Requirement already satisfied: opencv-python>=3.0 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from gymnasium[other]) (4.11.0.86)
# Collecting seaborn>=0.13 (from gymnasium[other])
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from matplotlib>=3.0->gymnasium[other]) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from matplotlib>=3.0->gymnasium[other]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from matplotlib>=3.0->gymnasium[other]) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from matplotlib>=3.0->gymnasium[other]) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /home/stalaei/.local/lib/python3.10/site-packages (from matplotlib>=3.0->gymnasium[other]) (23.2)
# Requirement already satisfied: pillow>=8 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from matplotlib>=3.0->gymnasium[other]) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from matplotlib>=3.0->gymnasium[other]) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from matplotlib>=3.0->gymnasium[other]) (2.9.0.post0)
# Requirement already satisfied: decorator<6.0,>=4.0.2 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from moviepy>=1.0.0->gymnasium[other]) (5.2.1)
# Collecting imageio<3.0,>=2.5 (from moviepy>=1.0.0->gymnasium[other])
#   Downloading imageio-2.37.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting imageio_ffmpeg>=0.2.0 (from moviepy>=1.0.0->gymnasium[other])
#   Downloading imageio_ffmpeg-0.6.0-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting proglog<=1.0.0 (from moviepy>=1.0.0->gymnasium[other])
#   Downloading proglog-0.1.10-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: python-dotenv>=0.10 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from moviepy>=1.0.0->gymnasium[other]) (1.1.0)
# Collecting pillow>=8 (from matplotlib>=3.0->gymnasium[other])
#   Downloading pillow-10.4.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (9.2 kB)
# Requirement already satisfied: pandas>=1.2 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from seaborn>=0.13->gymnasium[other]) (2.2.3)
# Requirement already satisfied: pytz>=2020.1 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from pandas>=1.2->seaborn>=0.13->gymnasium[other]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from pandas>=1.2->seaborn>=0.13->gymnasium[other]) (2025.2)
# Requirement already satisfied: tqdm in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from proglog<=1.0.0->moviepy>=1.0.0->gymnasium[other]) (4.67.1)
# Requirement already satisfied: six>=1.5 in /home/stalaei/miniconda3/envs/DeepRL/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.0->gymnasium[other]) (1.17.0)
# Downloading moviepy-2.1.2-py3-none-any.whl (126 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.7/126.7 kB 6.8 MB/s eta 0:00:00
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 26.0 MB/s eta 0:00:00
# Downloading imageio-2.37.0-py3-none-any.whl (315 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 315.8/315.8 kB 32.1 MB/s eta 0:00:00
# Downloading imageio_ffmpeg-0.6.0-py3-none-manylinux2014_x86_64.whl (29.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.5/29.5 MB 53.0 MB/s eta 0:00:00:00:0100:01
# Downloading pillow-10.4.0-cp310-cp310-manylinux_2_28_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 83.7 MB/s eta 0:00:00:00:01
# Downloading proglog-0.1.10-py3-none-any.whl (6.1 kB)
# Installing collected packages: proglog, pillow, imageio_ffmpeg, imageio, seaborn, moviepy
#   Attempting uninstall: pillow
#     Found existing installation: pillow 11.1.0
#     Uninstalling pillow-11.1.0:
#       Successfully uninstalled pillow-11.1.0
# Successfully installed imageio-2.37.0 imageio_ffmpeg-0.6.0 moviepy-2.1.2 pillow-10.4.0 proglog-0.1.10 seaborn-0.13.2
#
# [notice] A new release of pip is available: 23.3.2 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
# !python -m rl_zoo3.push_to_hub  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --repo-name DeepRL-dqn-SpaceInvadersNoFrameskip-v4 -orga stalaei -f logs/
# Out:
# Loading latest experiment, id=4
# Loading logs/dqn/SpaceInvadersNoFrameskip-v4_4/SpaceInvadersNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.10.2+c9d4b19)
# [Powered by Stella]
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Uploading to stalaei/DeepRL-dqn-SpaceInvadersNoFrameskip-v4, make sure to have the rights
# ℹ This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to some
# minutes if video generation is activated. This is a work in progress: if you
# encounter a bug, please open an issue.
# Fetching 14 files:   0%|                                 | 0/14 [00:00<?, ?it/s]
# results.json: 100%|████████████████████████████| 151/151 [00:00<00:00, 1.89MB/s]
# Fetching 14 files: 100%|████████████████████████| 14/14 [00:00<00:00, 51.12it/s]
# Saving model to: hub/DeepRL-dqn-SpaceInvadersNoFrameskip-v4/dqn-SpaceInvadersNoFrameskip-v4
# Saving video to /tmp/tmpbrhs5a8d/-step-0-to-step-1000.mp4
# MoviePy - Building video /tmp/tmpbrhs5a8d/-step-0-to-step-1000.mp4.
# MoviePy - Writing video /tmp/tmpbrhs5a8d/-step-0-to-step-1000.mp4
#
# MoviePy - Done !
# MoviePy - video ready /tmp/tmpbrhs5a8d/-step-0-to-step-1000.mp4
# ✘ 'DummyVecEnv' object has no attribute 'video_recorder'
# ✘ We are unable to generate a replay of your agent, the package_to_hub
# process continues
# ✘ Please open an issue at
# https://github.com/huggingface/huggingface_sb3/issues
# ℹ Pushing repo DeepRL-dqn-SpaceInvadersNoFrameskip-v4 to the Hugging
# Face Hub
# policy.optimizer.pth:   0%|                         | 0.00/13.5M [00:00<?, ?B/s]
# policy.pth:   0%|                                   | 0.00/13.5M [00:00<?, ?B/s]
#
# dqn-SpaceInvadersNoFrameskip-v4.zip:   0%|          | 0.00/27.2M [00:00<?, ?B/s]
#
#
# Upload 4 LFS files:   0%|                                 | 0/4 [00:00<?, ?it/s]
#
#
#
# policy.optimizer.pth:  26%|████▏           | 3.49M/13.5M [00:00<00:00, 34.6MB/s]
#
# dqn-SpaceInvadersNoFrameskip-v4.zip:  10%| | 2.67M/27.2M [00:00<00:00, 26.7MB/s]
# policy.optimizer.pth:  60%|█████████▌      | 8.04M/13.5M [00:00<00:00, 40.4MB/s]
#
# train_eval_metrics.zip: 100%|███████████████| 38.3k/38.3k [00:00<00:00, 155kB/s]
#
# policy.pth:   9%|██▍                       | 1.26M/13.5M [00:00<00:02, 5.32MB/s]
# policy.pth:  20%|█████▎                    | 2.74M/13.5M [00:00<00:01, 7.92MB/s]
# policy.pth:  26%|██████▊                   | 3.54M/13.5M [00:00<00:01, 6.79MB/s]
#
# dqn-SpaceInvadersNoFrameskip-v4.zip:  59%|▌| 16.0M/27.2M [00:00<00:00, 25.4MB/s]
# policy.pth:  42%|██████████▉               | 5.69M/13.5M [00:00<00:00, 11.0MB/s]
#
# dqn-SpaceInvadersNoFrameskip-v4.zip:  82%|▊| 22.5M/27.2M [00:00<00:00, 33.8MB/s]
# policy.optimizer.pth: 100%|████████████████| 13.5M/13.5M [00:00<00:00, 15.5MB/s]
#
#
#
# dqn-SpaceInvadersNoFrameskip-v4.zip: 100%|█| 27.2M/27.2M [00:01<00:00, 25.3MB/s]
# policy.pth: 100%|██████████████████████████| 13.5M/13.5M [00:01<00:00, 10.3MB/s]
#
#
#
# Upload 4 LFS files: 100%|█████████████████████████| 4/4 [00:01<00:00,  2.69it/s]
# ℹ Your model is pushed to the hub. You can view your model here:
# https://huggingface.co/stalaei/DeepRL-dqn-SpaceInvadersNoFrameskip-v4

# %% [markdown]
# #### Solution

# %%
# !python -m rl_zoo3.push_to_hub  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --repo-name dqn-SpaceInvadersNoFrameskip-v4  -orga ThomasSimonini  -f logs/

# %% [markdown]
# ###.

# %% [markdown]
# Congrats 🥳 you've just trained and uploaded your first Deep Q-Learning agent using RL-Baselines-3 Zoo. The script above should have displayed a link to a model repository such as https://huggingface.co/ThomasSimonini/dqn-SpaceInvadersNoFrameskip-v4. When you go to this link, you can:
#
# - See a **video preview of your agent** at the right.
# - Click "Files and versions" to see all the files in the repository.
# - Click "Use in stable-baselines3" to get a code snippet that shows how to load the model.
# - A model card (`README.md` file) which gives a description of the model and the hyperparameters you used.
#
# Under the hood, the Hub uses git-based repositories (don't worry if you don't know what git is), which means you can update the model with new versions as you experiment and improve your agent.
#
# **Compare the results of your agents with your classmates** using the [leaderboard](https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard) 🏆

# %% [markdown]
# ## Load a powerful trained model 🔥
# - The Stable-Baselines3 team uploaded **more than 150 trained Deep Reinforcement Learning agents on the Hub**.
#
# You can find them here: 👉 https://huggingface.co/sb3
#
# Some examples:
# - Asteroids: https://huggingface.co/sb3/dqn-AsteroidsNoFrameskip-v4
# - Beam Rider: https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4
# - Breakout: https://huggingface.co/sb3/dqn-BreakoutNoFrameskip-v4
# - Road Runner: https://huggingface.co/sb3/dqn-RoadRunnerNoFrameskip-v4
#
# Let's load an agent playing Beam Rider: https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4

# %%
# %%html
# <video controls autoplay><source src="https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4/resolve/main/replay.mp4" type="video/mp4"></video>
# Out:
# <video controls autoplay><source src="https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4/resolve/main/replay.mp4" type="video/mp4"></video>

# %% [markdown]
# 1. We download the model using `rl_zoo3.load_from_hub`, and place it in a new folder that we can call `rl_trained`

# %%
# Download model and save it into the logs/ folder
# !python -m rl_zoo3.load_from_hub --algo dqn --env BeamRiderNoFrameskip-v4 -orga sb3 -f rl_trained/

# %% [markdown]
# 2. Let's evaluate if for 5000 timesteps

# %%
# !python -m rl_zoo3.enjoy --algo dqn --env BeamRiderNoFrameskip-v4 -n 5000  -f rl_trained/ --no-render

# %% [markdown]
# Why not trying to train your own **Deep Q-Learning Agent playing BeamRiderNoFrameskip-v4? 🏆.**
#
# If you want to try, check https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4#hyperparameters **in the model card, you have the hyperparameters of the trained agent.**

# %% [markdown]
# But finding hyperparameters can be a daunting task. Fortunately, we'll see in the next Unit, how we can **use Optuna for optimizing the Hyperparameters 🔥.**

# %% [markdown]
# ## Some additional challenges 🏆
# The best way to learn **is to try things by your own**!
#
# In the [Leaderboard](https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard) you will find your agents. Can you get to the top?
#
# Here's a list of environments you can try to train your agent with:
# - BeamRiderNoFrameskip-v4
# - BreakoutNoFrameskip-v4
# - EnduroNoFrameskip-v4
# - PongNoFrameskip-v4
#
# Also, **if you want to learn to implement Deep Q-Learning by yourself**, you definitely should look at CleanRL implementation: https://github.com/vwxyzjn/cleanrl/blob/master/cleanrl/dqn_atari.py
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit4/atari-envs.gif" alt="Environments"/>

# %% [markdown]
# ________________________________________________________________________
# Congrats on finishing this chapter!
#
# If you’re still feel confused with all these elements...it's totally normal! **This was the same for me and for all people who studied RL.**
#
# Take time to really **grasp the material before continuing and try the additional challenges**. It’s important to master these elements and having a solid foundations.
#
# In the next unit, **we’re going to learn about [Optuna](https://optuna.org/)**. One of the most critical task in Deep Reinforcement Learning is to find a good set of training hyperparameters. And Optuna is a library that helps you to automate the search.

# %% [markdown]
# ### This is a course built with you 👷🏿‍♀️
#
# Finally, we want to improve and update the course iteratively with your feedback. If you have some, please fill this form 👉 https://forms.gle/3HgA7bEHwAmmLfwh9
#
# We're constantly trying to improve our tutorials, so **if you find some issues in this notebook**, please [open an issue on the Github Repo](https://github.com/huggingface/deep-rl-class/issues).

# %% [markdown]
# See you on Bonus unit 2! 🔥

# %% [markdown]
# ### Keep Learning, Stay Awesome 🤗
